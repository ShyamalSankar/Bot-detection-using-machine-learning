# %%
import pandas as pd
import tweepy
import re
import numpy as np
import os
import PIL
import requests
from sklearn.utils import shuffle
from PIL import Image

# %% [markdown]
# #### Scraping user data for mixed datasets

# %%
df_genuine = pd.read_csv("users_genuine.csv")
df_rtbust = pd.read_csv("cresci-rtbust-2019.csv", header = None)
df_gilani = pd.read_csv("gilani-2017.csv", header = None)

# %%
new_df = df_genuine['id'].to_frame()
new_df['account_type'] = 'human'

df_rtbust.columns = ['id', 'account_type']
df_gilani.columns = ['id', 'account_type']

new_df1 = pd.concat([new_df, df_rtbust])
new_df2 = pd.concat([new_df1, df_gilani])
new_df2 = new_df2.reset_index(drop = True)

# %%
new_df2 = new_df2.drop_duplicates(subset=['id'], keep='first')
df_twitter = new_df2.reset_index(drop = True)
df_twitter
# Out:
#                 id account_type
# 0     1.502026e+09        human
# 1     2.492782e+09        human
# 2     2.932123e+08        human
# 3     1.918397e+08        human
# 4     3.020965e+09        human
# ...            ...          ...
# 6854  6.876519e+07        human
# 6855  7.824970e+17        human
# 6856  1.341644e+08        human
# 6857  7.237812e+07        human
# 6858  1.507112e+08        human
#
# [6859 rows x 2 columns]

# %%
df_twitter['id'] = df_twitter['id'].astype(int).astype(str)
df_twitter['id'] = df_twitter['id'].str.replace('-','')
df_twitter
# Out:
#               id account_type
# 0     1502026416        human
# 1     2147483648        human
# 2      293212315        human
# 3      191839658        human
# 4     2147483648        human
# ...          ...          ...
# 6854    68765193        human
# 6855  2147483648        human
# 6856   134164413        human
# 6857    72378123        human
# 6858   150711216        human
#
# [6859 rows x 2 columns]

# %%
# name, username, created_at, protected, verified, location, description, 
# public_metrics (followers_count, following_count, tweets_count)
# id, tweets, account_type
# CHECK
# favourites_count, geo_enabled, statuses_count
# average_tweets_per_day, account_age_days

def get_twitter_dictionary(id_list, account_type_dict, client):
    twitter_data = {'id':[], 'name':[], 'username':[], 'created_at':[], 
                    'protected':[], 'verified':[], 'url': [], 'profile_image_url':[],
                    'location':[], 'description':[], 'followers_count':[], 'following_count':[],
                    'tweet_count':[], 'listed_count':[], 'account_type':[]}

    user_info = client.get_users(ids = id_list, user_fields=["created_at", "description", "entities", 
                                                             "id", "location", "name", "profile_image_url", 
                                                             "protected", "public_metrics", "url", "username", 
                                                             "verified", "withheld"])
    
    user_dict = dict()
    info_list = user_info[0]
    
    if info_list == None:
        return twitter_data
    
    for each_user in info_list:
        data = each_user.data
        user_dict[data['id']] = data

    for item in user_dict.items():
        each_user_id = item[0]
        each_user_account_type = account_type_dict[each_user_id]
        each_user_info = item[1]
        twitter_data['id'].append(each_user_id)
        twitter_data['account_type'].append(each_user_account_type)
        each_dictionary = user_dict[each_user_id]
        
        if 'name' in each_dictionary:
                twitter_data['name'].append(each_dictionary['name'])
        else:
            twitter_data['name'].append('')

        if 'username' in each_dictionary:
            twitter_data['username'].append(each_dictionary['username'])
        else:
            twitter_data['username'].append('')

        if 'created_at' in each_dictionary:
            twitter_data['created_at'].append(each_dictionary['created_at'])
        else:
            twitter_data['created_at'].append('')

        if 'protected' in each_dictionary:
            twitter_data['protected'].append(each_dictionary['protected'])
        else:
            twitter_data['protected'].append('')

        if 'verified' in each_dictionary:
            twitter_data['verified'].append(each_dictionary['verified'])
        else:
            twitter_data['verified'].append('')
        
        if 'url' in each_dictionary:
            twitter_data['url'].append(each_dictionary['url'])
        else:
            twitter_data['url'].append('')
            
        if 'profile_image_url' in each_dictionary:
            twitter_data['profile_image_url'].append(each_dictionary['profile_image_url'])
        else:
            twitter_data['profile_image_url'].append('')

        if 'location' in each_dictionary:
            twitter_data['location'].append(each_dictionary['location'])
        else:
            twitter_data['location'].append('')

        if 'description' in each_dictionary:
            twitter_data['description'].append(each_dictionary['description'])
        else:
            twitter_data['description'].append('')

        if 'public_metrics' in each_dictionary:
            each_pub_metric = each_dictionary['public_metrics']

            if 'followers_count' in each_pub_metric:
                twitter_data['followers_count'].append(each_pub_metric['followers_count'])
            else:
                twitter_data['followers_count'].append('')

            if 'following_count' in each_pub_metric:
                twitter_data['following_count'].append(each_pub_metric['following_count'])
            else:
                twitter_data['following_count'].append('')

            if 'tweet_count' in each_pub_metric:
                twitter_data['tweet_count'].append(each_pub_metric['tweet_count'])
            else:
                twitter_data['tweet_count'].append('')
                
            if 'listed_count' in each_pub_metric:
                twitter_data['listed_count'].append(each_pub_metric['listed_count'])
            else:
                twitter_data['listed_count'].append('')
                
        else:
            twitter_data['followers_count'].append('')
            twitter_data['following_count'].append('')
            twitter_data['tweet_count'].append('')
            twitter_data['listed_count'].append('')

    return twitter_data

# %%
bearer_token1 = 'AAAAAAAAAAAAAAAAAAAAADuChwEAAAAAyd5NyoPPZfk%2FiBwmc2mC9me33RA%3DTFH93ScdBzcU6OHVLLsTDHKLW599NhhPoEBTPi0KFWdAEbmFth'
bearer_token2 = 'AAAAAAAAAAAAAAAAAAAAAAK%2FhwEAAAAAtHE4qeLy3hhb660R143d7IOccaE%3D8qaWBsRfyKMigZj2jBVVFNifngriGAkuwJv74wOOs05m6XNReW'
bearer_token3 = 'AAAAAAAAAAAAAAAAAAAAAOjAhwEAAAAAzL7KuhOWC8yybNEnpbXPfhmCpMA%3Ds3R17rqHTA6rqR2kDhis6mrjFWYth3VgLgUu6w354BlwY2hGH8'

bearer_tokens = [bearer_token2, bearer_token1, bearer_token3]

# %%
start_index = 0

for each_round in range(1):
    token = bearer_tokens[each_round%3]
    client = tweepy.Client(bearer_token= token)
    print(token)
    
    twitter_data_list = []
    for i in range(69):
        start = i * 100
        end = start + 100
        df_tweet_subset = df_twitter[start: end]
        acc_type_dict = dict(zip(df_tweet_subset["id"], df_tweet_subset["account_type"]))
        each_id_list = list(df_tweet_subset["id"])
        print(str(start) + " : " + str(end)) 
        twitter_data = get_twitter_dictionary(each_id_list, acc_type_dict, client)
        tweets_df = pd.DataFrame(twitter_data)
        twitter_data_list.append(tweets_df)
    
    start_index += 1
    
    combined_twitter_data = pd.concat(twitter_data_list)
        
    combined_twitter_data.to_csv(f'final_combined.csv')
    
    print("round" + str(each_round))
# Out:
# AAAAAAAAAAAAAAAAAAAAAAK%2FhwEAAAAAtHE4qeLy3hhb660R143d7IOccaE%3D8qaWBsRfyKMigZj2jBVVFNifngriGAkuwJv74wOOs05m6XNReW
# 0 : 100
# 100 : 200
# 200 : 300
# 300 : 400
# 400 : 500
# 500 : 600
# 600 : 700
# 700 : 800
# 800 : 900
# 900 : 1000
# 1000 : 1100
# 1100 : 1200
# 1200 : 1300
# 1300 : 1400
# 1400 : 1500
# 1500 : 1600
# 1600 : 1700
# 1700 : 1800
# 1800 : 1900
# 1900 : 2000
# 2000 : 2100
# 2100 : 2200
# 2200 : 2300
# 2300 : 2400
# 2400 : 2500
# 2500 : 2600
# 2600 : 2700
# 2700 : 2800
# 2800 : 2900
# 2900 : 3000
# 3000 : 3100
# 3100 : 3200
# 3200 : 3300
# 3300 : 3400
# 3400 : 3500
# 3500 : 3600
# 3600 : 3700
# 3700 : 3800
# 3800 : 3900
# 3900 : 4000
# 4000 : 4100
# 4100 : 4200
# 4200 : 4300
# 4300 : 4400
# 4400 : 4500
# 4500 : 4600
# 4600 : 4700
# 4700 : 4800
# 4800 : 4900
# 4900 : 5000
# 5000 : 5100
# 5100 : 5200
# 5200 : 5300
# 5300 : 5400
# 5400 : 5500
# 5500 : 5600
# 5600 : 5700
# 5700 : 5800
# 5800 : 5900
# 5900 : 6000
# 6000 : 6100
# 6100 : 6200
# 6200 : 6300
# 6300 : 6400
# 6400 : 6500
# 6500 : 6600
# 6600 : 6700
# 6700 : 6800
# 6800 : 6900
# round0

# %%
final_combined = combined_twitter_data

# %%
final_combined = final_combined.reset_index(inplace = False, drop = True)

# %%
final_combined['id'] = final_combined['id'].astype(str)

# %%
def has_profile_image(profile_image_url):
    if type(profile_image_url) == str:
        return profile_image_url.find("/default_profile_normal.png") == -1
    return False 

final_combined["has_profile_image"] = final_combined["profile_image_url"].apply(lambda x : has_profile_image(x))
final_combined
# Out:
#               id                     name         username  \
# 0     1502026416                      早川援         0918Bask
# 1      191839658                      bio      sweetalkmp3
# 2     1947320929                ❄McKayla❄  1Dniallprincess
# 3      255846106  Giselle | #SaveMacGyver  1GisellePizarro
# 4     1733095801            Nicole Romany    1Nicoleromany
# ...          ...                      ...              ...
# 4236    99561835                   Hassam    oficialHASSAM
# 4237    68765193              Gui Santana      oguisantana
# 4238   134164413       Relatable Feelings     omgrelatabIe
# 4239    72378123               Ömür Gedik        omurgedik
# 4240   150711216                 Yakozuki         yakozuki
#
#                     created_at  protected  verified                      url  \
# 0     2013-06-11T11:20:35.000Z      False     False
# 1     2010-09-17T14:02:10.000Z       True     False
# 2     2013-10-08T15:59:30.000Z      False     False
# 3     2011-02-22T04:37:34.000Z      False     False  https://t.co/XK9kMS2j8g
# 4     2013-09-05T20:52:02.000Z      False     False
# ...                        ...        ...       ...                      ...
# 4236  2009-12-26T19:38:35.000Z      False      True  https://t.co/RF02usHQhV
# 4237  2009-08-25T18:20:47.000Z      False      True
# 4238  2010-04-17T16:34:38.000Z      False     False  https://t.co/kzr5yPhiwI
# 4239  2009-09-07T20:49:11.000Z      False      True  https://t.co/cuvHMZqV7X
# 4240  2010-06-01T16:34:48.000Z      False     False
#
#                                       profile_image_url  \
# 0     https://pbs.twimg.com/profile_images/100439306...
# 1     https://pbs.twimg.com/profile_images/758761054...
# 2     https://pbs.twimg.com/profile_images/100270690...
# 3     https://pbs.twimg.com/profile_images/108000539...
# 4     https://pbs.twimg.com/profile_images/128788084...
# ...                                                 ...
# 4236  https://pbs.twimg.com/profile_images/163216059...
# 4237  https://pbs.twimg.com/profile_images/144232348...
# 4238  https://pbs.twimg.com/profile_images/154806296...
# 4239  https://pbs.twimg.com/profile_images/155565314...
# 4240  https://pbs.twimg.com/profile_images/159514060...
#
#                             location  \
# 0
# 1
# 2                             Alaska
# 3                 Antofagasta, Chile
# 4
# ...                              ...
# 4236               Bogota - Colombia
# 4237                       São Paulo
# 4238  Frankfurt am Main, Deutschland
# 4239                          Turkey
# 4240                  Estados Unidos
#
#                                             description  followers_count  \
# 0                                           好きこそ物の上手なれ。              242
# 1                    no longer here I'm @toujoursbeiles             1690
# 2     Live, Young, Wild and Free ♊️ “Attitude Is Eve...              610
# 3     29-year-old Bilingual Management student by da...              102
# 4     Multi Media Journalist/Producer CCNTV6 \nWork ...             1349
# ...                                                 ...              ...
# 4236                Hassam Contacto: Info@hassam.com.co          1443429
# 4237                                          Humorista           910714
# 4238  Tweeting relatable thoughts & feelings. Just t...           893608
# 4239  @hacikodernek Kurucu Başkanı, POPSAV YK Üyesi,...           830808
# 4240                                               soon          1057125
#
#       following_count  tweet_count  listed_count account_type  \
# 0                 250         3921             1        human
# 1                 791       255840            55        human
# 2                  76        13887             8        human
# 3                  83        94231             8        human
# 4                 382         9999            21        human
# ...               ...          ...           ...          ...
# 4236              356        56097          1051        human
# 4237              844         8770           519        human
# 4238            48584        56921          2590        human
# 4239           104905        31037           977        human
# 4240                0        20125          1595        human
#
#       has_profile_image
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ...                 ...
# 4236               True
# 4237               True
# 4238               True
# 4239               True
# 4240               True
#
# [4241 rows x 16 columns]

# %%
final_combined.to_csv('final_combined.csv')

# %% [markdown]
# #### getting profile pictures for bots and humans separately for mixed datasets

# %%
df2 = final_combined[final_combined["has_profile_image"] == True][["id", "profile_image_url", "account_type"]]
df2_bots = df2[df2['account_type'] == 'bot']
df2_humans = df2[df2['account_type'] == 'human']
df2_bots = df2_bots.reset_index()
df2_humans = df2_humans.reset_index()

# %%
df2_bots
# Out:
#      index          id                                  profile_image_url  \
# 0     2148   390617262  https://pbs.twimg.com/profile_images/175289747...
# 1     2150  1154282738  https://pbs.twimg.com/profile_images/321630323...
# 2     2152  1357959324  https://pbs.twimg.com/profile_images/153216197...
# 3     2153   327555341  https://pbs.twimg.com/profile_images/161038836...
# 4     2154  1459595030  https://pbs.twimg.com/profile_images/101206593...
# ..     ...         ...                                                ...
# 874   3165   440784095  https://pbs.twimg.com/profile_images/162257865...
# 875   3166   297174372  https://pbs.twimg.com/profile_images/113132241...
# 876   3167   112431151  https://pbs.twimg.com/profile_images/162406150...
# 877   3168    14614833  https://pbs.twimg.com/profile_images/141964925...
# 878   3169    16736535  https://pbs.twimg.com/profile_images/877980023...
#
#     account_type
# 0            bot
# 1            bot
# 2            bot
# 3            bot
# 4            bot
# ..           ...
# 874          bot
# 875          bot
# 876          bot
# 877          bot
# 878          bot
#
# [879 rows x 4 columns]

# %%
df2_humans
# Out:
#       index          id                                  profile_image_url  \
# 0         0  1502026416  https://pbs.twimg.com/profile_images/100439306...
# 1         1   191839658  https://pbs.twimg.com/profile_images/758761054...
# 2         2  1947320929  https://pbs.twimg.com/profile_images/100270690...
# 3         3   255846106  https://pbs.twimg.com/profile_images/108000539...
# 4         4  1733095801  https://pbs.twimg.com/profile_images/128788084...
# ...     ...         ...                                                ...
# 3336   4236    99561835  https://pbs.twimg.com/profile_images/163216059...
# 3337   4237    68765193  https://pbs.twimg.com/profile_images/144232348...
# 3338   4238   134164413  https://pbs.twimg.com/profile_images/154806296...
# 3339   4239    72378123  https://pbs.twimg.com/profile_images/155565314...
# 3340   4240   150711216  https://pbs.twimg.com/profile_images/159514060...
#
#      account_type
# 0           human
# 1           human
# 2           human
# 3           human
# 4           human
# ...           ...
# 3336        human
# 3337        human
# 3338        human
# 3339        human
# 3340        human
#
# [3341 rows x 4 columns]

# %%
for index, row in df2_bots.iterrows():
    try:
        user_id = row["id"]
        img_url = row["profile_image_url"]
        extension = os.path.splitext(img_url)[-1]
        filename = str(user_id) + extension.lower()
        directory = './pictures/bot/' + filename
        img = Image.open(requests.get(img_url, stream = True).raw).convert('RGB')
        img.save(directory)
    except Exception as e:
        error_msg = str(e) + " " + str(user_id) + " " + str(img_url)
        print(error_msg)

# %%
for index, row in df2_humans.iterrows():
    try:
        user_id = row["id"]
        img_url = row["profile_image_url"]
        extension = os.path.splitext(img_url)[-1]
        filename = str(user_id) + extension.lower()
        directory = './pictures/human/' + filename
        img = Image.open(requests.get(img_url, stream = True).raw).convert('RGB')
        img.save(directory)
    except Exception as e:
        error_msg = str(e) + " " + str(user_id) + " " + str(img_url)
        print(error_msg)
# Out:
# unknown file extension:  763095612 https://pbs.twimg.com/profile_images/2514776452/U5hTn1oi_normal

# %% [markdown]
# #### scraping more legitamate users data from genuine dataset

# %%
df_legit = pd.read_csv('legitimate_users.csv')

# %%
df_legit
# Out:
#          UserID       CreatedAt     CollectedAt  NumerOfFollowings  \
# 0           614   13/7/06 15:30  20/11/09 23:56                510
# 1          1038   15/7/06 16:12   16/11/09 5:12                304
# 2          1437   16/7/06 12:29  16/11/09 16:25                 45
# 3          2615   19/7/06 23:23  27/11/09 18:34                211
# 4          3148   26/7/06 14:17  20/11/09 17:35               7346
# ...         ...             ...             ...                ...
# 19271  93390990   29/11/09 6:34   29/11/09 7:50                  5
# 19272  93402679   29/11/09 7:47   29/11/09 7:56                 20
# 19273  93419256   29/11/09 9:23   29/11/09 9:30                  0
# 19274  93426370  29/11/09 10:04  29/11/09 10:13                 20
# 19275  93442002  29/11/09 11:27  29/11/09 11:36                  1
#
#        NumberOfFollowers  NumberOfTweets  LengthOfScreenName  \
# 0                    350            3265                  10
# 1                    443            4405                   7
# 2                     73             725                   6
# 3                    230             211                   7
# 4                   7244           11438                   8
# ...                  ...             ...                 ...
# 19271                  0               5                  11
# 19272                  1               1                  12
# 19273                  0               1                   8
# 19274                  1               1                  10
# 19275                  0               1                   7
#
#        LengthOfDescriptionInUserProfile
# 0                                     34
# 1                                    156
# 2                                     37
# 3                                      0
# 4                                     97
# ...                                  ...
# 19271                                  0
# 19272                                  0
# 19273                                  0
# 19274                                  0
# 19275                                  0
#
# [19276 rows x 8 columns]

# %%
df_legit_new = df_legit.sample(n=15000, random_state=1)
df_legit_new = df_legit_new.reset_index(drop = True)

new_df_legit = df_legit_new['UserID'].to_frame()
new_df_legit['account_type'] = 'human'
new_df_legit = new_df_legit.rename(columns = {'UserID': 'id'})
new_df_legit['id'] = new_df_legit['id'].astype(str)
new_df_legit
# Out:
#              id account_type
# 0      15855162        human
# 1      79561384        human
# 2      19737713        human
# 3      75675003        human
# 4      60748828        human
# ...         ...          ...
# 14995  50678874        human
# 14996  41842039        human
# 14997  26964352        human
# 14998  87335770        human
# 14999  33562238        human
#
# [15000 rows x 2 columns]

# %%
start_index = 0

for each_round in range(1):
    token = bearer_tokens[each_round%3]
    client = tweepy.Client(bearer_token= token)
    print(token)
    
    twitter_data_list = []
    for i in range(150):
        start = i * 100
        end = start + 100
        df_tweet_subset = new_df_legit[start: end]
        acc_type_dict = dict(zip(df_tweet_subset["id"], df_tweet_subset["account_type"]))
        each_id_list = list(df_tweet_subset["id"])
        print(str(start) + " : " + str(end)) 
        twitter_data = get_twitter_dictionary(each_id_list, acc_type_dict, client)
        tweets_df = pd.DataFrame(twitter_data)
        twitter_data_list.append(tweets_df)
    
    start_index += 1
    
    combined_twitter_data = pd.concat(twitter_data_list)
        
    combined_twitter_data.to_csv(f'final_combined_legit.csv')
    
    print("round" + str(each_round))
# Out:
# AAAAAAAAAAAAAAAAAAAAAAK%2FhwEAAAAAtHE4qeLy3hhb660R143d7IOccaE%3D8qaWBsRfyKMigZj2jBVVFNifngriGAkuwJv74wOOs05m6XNReW
# 0 : 100
# 100 : 200
# 200 : 300
# 300 : 400
# 400 : 500
# 500 : 600
# 600 : 700
# 700 : 800
# 800 : 900
# 900 : 1000
# 1000 : 1100
# 1100 : 1200
# 1200 : 1300
# 1300 : 1400
# 1400 : 1500
# 1500 : 1600
# 1600 : 1700
# 1700 : 1800
# 1800 : 1900
# 1900 : 2000
# 2000 : 2100
# 2100 : 2200
# 2200 : 2300
# 2300 : 2400
# 2400 : 2500
# 2500 : 2600
# 2600 : 2700
# 2700 : 2800
# 2800 : 2900
# 2900 : 3000
# 3000 : 3100
# 3100 : 3200
# 3200 : 3300
# 3300 : 3400
# 3400 : 3500
# 3500 : 3600
# 3600 : 3700
# 3700 : 3800
# 3800 : 3900
# 3900 : 4000
# 4000 : 4100
# 4100 : 4200
# 4200 : 4300
# 4300 : 4400
# 4400 : 4500
# 4500 : 4600
# 4600 : 4700
# 4700 : 4800
# 4800 : 4900
# 4900 : 5000
# 5000 : 5100
# 5100 : 5200
# 5200 : 5300
# 5300 : 5400
# 5400 : 5500
# 5500 : 5600
# 5600 : 5700
# 5700 : 5800
# 5800 : 5900
# 5900 : 6000
# 6000 : 6100
# 6100 : 6200
# 6200 : 6300
# 6300 : 6400
# 6400 : 6500
# 6500 : 6600
# 6600 : 6700
# 6700 : 6800
# 6800 : 6900
# 6900 : 7000
# 7000 : 7100
# 7100 : 7200
# 7200 : 7300
# 7300 : 7400
# 7400 : 7500
# 7500 : 7600
# 7600 : 7700
# 7700 : 7800
# 7800 : 7900
# 7900 : 8000
# 8000 : 8100
# 8100 : 8200
# 8200 : 8300
# 8300 : 8400
# 8400 : 8500
# 8500 : 8600
# 8600 : 8700
# 8700 : 8800
# 8800 : 8900
# 8900 : 9000
# 9000 : 9100
# 9100 : 9200
# 9200 : 9300
# 9300 : 9400
# 9400 : 9500
# 9500 : 9600
# 9600 : 9700
# 9700 : 9800
# 9800 : 9900
# 9900 : 10000
# 10000 : 10100
# 10100 : 10200
# 10200 : 10300
# 10300 : 10400
# 10400 : 10500
# 10500 : 10600
# 10600 : 10700
# 10700 : 10800
# 10800 : 10900
# 10900 : 11000
# 11000 : 11100
# 11100 : 11200
# 11200 : 11300
# 11300 : 11400
# 11400 : 11500
# 11500 : 11600
# 11600 : 11700
# 11700 : 11800
# 11800 : 11900
# 11900 : 12000
# 12000 : 12100
# 12100 : 12200
# 12200 : 12300
# 12300 : 12400
# 12400 : 12500
# 12500 : 12600
# 12600 : 12700
# 12700 : 12800
# 12800 : 12900
# 12900 : 13000
# 13000 : 13100
# 13100 : 13200
# 13200 : 13300
# 13300 : 13400
# 13400 : 13500
# 13500 : 13600
# 13600 : 13700
# 13700 : 13800
# 13800 : 13900
# 13900 : 14000
# 14000 : 14100
# 14100 : 14200
# 14200 : 14300
# 14300 : 14400
# 14400 : 14500
# 14500 : 14600
# 14600 : 14700
# 14700 : 14800
# 14800 : 14900
# 14900 : 15000
# round0

# %%
final_combined_legit = combined_twitter_data

# %%
final_combined_legit = final_combined_legit.reset_index(inplace = False, drop = True)

# %%
final_combined_legit['id'] = final_combined_legit['id'].astype(str)

# %%
final_combined_legit["has_profile_image"] = final_combined_legit["profile_image_url"].apply(lambda x : has_profile_image(x))
final_combined_legit
# Out:
#              id                name        username                created_at  \
# 0      19737713   Elizabeth Alraune          JoLoPe  2009-01-29T22:03:40.000Z
# 1      60748828       Robin Emilian   sulphurandtea  2009-07-27T23:47:48.000Z
# 2      92155484       Jasmine Doria        JasDoria  2009-11-24T00:25:18.000Z
# 3      46499681         🦄 | #BLM ✊🏿    thatsclaudia  2009-06-11T21:43:51.000Z
# 4      15590821            DonnaKat     DonnaKatTzu  2008-07-24T23:24:02.000Z
# ...         ...                 ...             ...                       ...
# 11333  15270176      garybaumgarten  garybaumgarten  2008-06-29T12:16:19.000Z
# 11334  77316007         Márcio Luis     marcioluis_  2009-09-25T21:31:03.000Z
# 11335  50678874                  PM           pas07  2009-06-25T15:39:54.000Z
# 11336  41842039  Renan F. F da Rosa     renaanrosaa  2009-05-22T16:10:35.000Z
# 11337  26964352  D.A. GOT THAT DOPE  dagotthatdope1  2009-03-27T06:44:16.000Z
#
#        protected  verified                      url  \
# 0          False     False     http://t.co/J6DDq5gJ
# 1           True     False
# 2           True     False
# 3           True     False
# 4          False     False
# ...          ...       ...                      ...
# 11333      False     False  https://t.co/z9zZbLFAHe
# 11334      False     False   http://t.co/3fimtOJirK
# 11335      False     False
# 11336      False     False
# 11337      False     False  https://t.co/hCXBRn6n7E
#
#                                        profile_image_url  \
# 0      https://pbs.twimg.com/profile_images/502992423...
# 1      https://pbs.twimg.com/profile_images/335181244...
# 2      https://pbs.twimg.com/profile_images/378800000...
# 3      https://pbs.twimg.com/profile_images/162767550...
# 4      https://pbs.twimg.com/profile_images/113813687...
# ...                                                  ...
# 11333  https://pbs.twimg.com/profile_images/514448560...
# 11334  https://pbs.twimg.com/profile_images/136084962...
# 11335  https://pbs.twimg.com/profile_images/133071869...
# 11336  https://pbs.twimg.com/profile_images/277137399...
# 11337  https://pbs.twimg.com/profile_images/159569471...
#
#                              location  \
# 0                          everywhere
# 1
# 2                              HAWAII
# 3                  📍currently in Rome
# 4                     Bonne Terre, MO
# ...                               ...
# 11333                        New York
# 11334   tourino, feio, muito amigo. 웃
# 11335                       Endonesah
# 11336
# 11337                 Los Angeles, CA
#
#                                              description  followers_count  \
# 0      I love to read and write, but am not a big fan...             3664
# 1                                                                      10
# 2      imagination is the key to your world of advent...               56
# 3      🌠 26🔸INFP-T🔸\npisces ☼ capricorn ↑ taurus ☽ 🎥 ...             3958
# 4            Pureblood: unmasked, unvaxxed and unafraid.              800
# ...                                                  ...              ...
# 11333  Journalist for more than 5 decades. Opinions m...             1633
# 11334                                                                  99
# 11335           No Self-Confidence and Less Self-Control              246
# 11336  um jovem adorador,gosto muito de musica,fotogr...              369
# 11337  🗣️d.a. got that DOPE❗️ producer+writer+executi...             7453
#
#        following_count  tweet_count  listed_count account_type  \
# 0                 4640        28949            88        human
# 1                    0         1968             0        human
# 2                  299         1181             0        human
# 3                 2890       251180            99        human
# 4                 1223        39877            45        human
# ...                ...          ...           ...          ...
# 11333             1010        46322            71        human
# 11334              180          171             1        human
# 11335              196        41235             1        human
# 11336              378         1894             1        human
# 11337              510        26524            44        human
#
#        has_profile_image
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 11333               True
# 11334               True
# 11335               True
# 11336               True
# 11337               True
#
# [11338 rows x 16 columns]

# %%
final_combined_legit.to_csv('final_combined_legit.csv')

# %% [markdown]
# #### getting profile pictures for bots and humans separately for genuine dataset

# %%
df3 = final_combined_legit[final_combined_legit["has_profile_image"] == True]
df3
# Out:
#              id                name        username                created_at  \
# 0      19737713   Elizabeth Alraune          JoLoPe  2009-01-29T22:03:40.000Z
# 1      60748828       Robin Emilian   sulphurandtea  2009-07-27T23:47:48.000Z
# 2      92155484       Jasmine Doria        JasDoria  2009-11-24T00:25:18.000Z
# 3      46499681         🦄 | #BLM ✊🏿    thatsclaudia  2009-06-11T21:43:51.000Z
# 4      15590821            DonnaKat     DonnaKatTzu  2008-07-24T23:24:02.000Z
# ...         ...                 ...             ...                       ...
# 11333  15270176      garybaumgarten  garybaumgarten  2008-06-29T12:16:19.000Z
# 11334  77316007         Márcio Luis     marcioluis_  2009-09-25T21:31:03.000Z
# 11335  50678874                  PM           pas07  2009-06-25T15:39:54.000Z
# 11336  41842039  Renan F. F da Rosa     renaanrosaa  2009-05-22T16:10:35.000Z
# 11337  26964352  D.A. GOT THAT DOPE  dagotthatdope1  2009-03-27T06:44:16.000Z
#
#        protected  verified                      url  \
# 0          False     False     http://t.co/J6DDq5gJ
# 1           True     False
# 2           True     False
# 3           True     False
# 4          False     False
# ...          ...       ...                      ...
# 11333      False     False  https://t.co/z9zZbLFAHe
# 11334      False     False   http://t.co/3fimtOJirK
# 11335      False     False
# 11336      False     False
# 11337      False     False  https://t.co/hCXBRn6n7E
#
#                                        profile_image_url  \
# 0      https://pbs.twimg.com/profile_images/502992423...
# 1      https://pbs.twimg.com/profile_images/335181244...
# 2      https://pbs.twimg.com/profile_images/378800000...
# 3      https://pbs.twimg.com/profile_images/162767550...
# 4      https://pbs.twimg.com/profile_images/113813687...
# ...                                                  ...
# 11333  https://pbs.twimg.com/profile_images/514448560...
# 11334  https://pbs.twimg.com/profile_images/136084962...
# 11335  https://pbs.twimg.com/profile_images/133071869...
# 11336  https://pbs.twimg.com/profile_images/277137399...
# 11337  https://pbs.twimg.com/profile_images/159569471...
#
#                              location  \
# 0                          everywhere
# 1
# 2                              HAWAII
# 3                  📍currently in Rome
# 4                     Bonne Terre, MO
# ...                               ...
# 11333                        New York
# 11334   tourino, feio, muito amigo. 웃
# 11335                       Endonesah
# 11336
# 11337                 Los Angeles, CA
#
#                                              description  followers_count  \
# 0      I love to read and write, but am not a big fan...             3664
# 1                                                                      10
# 2      imagination is the key to your world of advent...               56
# 3      🌠 26🔸INFP-T🔸\npisces ☼ capricorn ↑ taurus ☽ 🎥 ...             3958
# 4            Pureblood: unmasked, unvaxxed and unafraid.              800
# ...                                                  ...              ...
# 11333  Journalist for more than 5 decades. Opinions m...             1633
# 11334                                                                  99
# 11335           No Self-Confidence and Less Self-Control              246
# 11336  um jovem adorador,gosto muito de musica,fotogr...              369
# 11337  🗣️d.a. got that DOPE❗️ producer+writer+executi...             7453
#
#        following_count  tweet_count  listed_count account_type  \
# 0                 4640        28949            88        human
# 1                    0         1968             0        human
# 2                  299         1181             0        human
# 3                 2890       251180            99        human
# 4                 1223        39877            45        human
# ...                ...          ...           ...          ...
# 11333             1010        46322            71        human
# 11334              180          171             1        human
# 11335              196        41235             1        human
# 11336              378         1894             1        human
# 11337              510        26524            44        human
#
#        has_profile_image
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 11333               True
# 11334               True
# 11335               True
# 11336               True
# 11337               True
#
# [10986 rows x 16 columns]

# %%
for index, row in df3.iterrows():
    try:
        user_id = row["id"]
        img_url = row["profile_image_url"]
        extension = os.path.splitext(img_url)[-1]
        filename = str(user_id) + extension.lower()
        directory = './pictures_legit/' + filename
        img = Image.open(requests.get(img_url, stream = True).raw).convert('RGB')
        img.save(directory)
    except Exception as e:
        error_msg = str(e) + " " + str(user_id) + " " + str(img_url)
        print(error_msg)
# Out:
# C:\Users\Emily Kok\anaconda3\lib\site-packages\PIL\Image.py:975: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# unknown file extension:  20951082 https://pbs.twimg.com/profile_images/2040396138/M9gCG9PT_normal
# unknown file extension:  43120355 https://pbs.twimg.com/profile_images/1872178349/gerF8xGl_normal
# unknown file extension:  16454640 https://pbs.twimg.com/profile_images/1134441944/4_normal
# unknown file extension:  49552710 https://pbs.twimg.com/profile_images/1620155215/photo_normal
# cannot identify image file <_io.BytesIO object at 0x000002406965DD10> 37628665 https://pbs.twimg.com/profile_images/195820525/favicon_normal.gif
# unknown file extension:  7919102 https://pbs.twimg.com/profile_images/2402664050/342788F9-7C90-41C8-AECF-CEB4F6A1527C_normal
# unknown file extension:  14710622 https://pbs.twimg.com/profile_images/1701701639/image_normal
# unknown file extension:  80208917 https://pbs.twimg.com/profile_images/1240599527/C2632j6z_normal
# unknown file extension:  46579801 https://pbs.twimg.com/profile_images/1862657277/gqOvL4Q5_normal
# unknown file extension:  42812912 https://pbs.twimg.com/profile_images/2319036085/2guYQzUT_normal
# unknown file extension:  67108679 https://pbs.twimg.com/profile_images/2487669256/photo_normal
# unknown file extension:  14754534 https://pbs.twimg.com/profile_images/2341656307/2VV7359K_normal
# unknown file extension:  92021672 https://pbs.twimg.com/profile_images/2359590063/Nt57o182_normal
# unknown file extension:  28099595 https://pbs.twimg.com/profile_images/2273137552/r23l0qSS_normal
# unknown file extension:  30971497 https://pbs.twimg.com/profile_images/1332095431/9O1Hk2Ls_normal
# unknown file extension:  51110726 https://pbs.twimg.com/profile_images/1433933458/photo_normal
# unknown file extension:  84695264 https://pbs.twimg.com/profile_images/577628433/111923304_1429__normal
# unknown file extension:  23287367 https://pbs.twimg.com/profile_images/1062093107/200646760_twitter_36563__normal
# unknown file extension:  52260186 https://pbs.twimg.com/profile_images/2481316772/PtSezap4_normal
# unknown file extension:  74180526 https://pbs.twimg.com/profile_images/1667347473/isJYe1pP_normal
# unknown file extension:  90059227 https://pbs.twimg.com/profile_images/2123175240/RK7IUrqC_normal
# cannot identify image file <_io.BytesIO object at 0x00000240697C6D10> 85970192 https://pbs.twimg.com/profile_images/507856143/4069307181_00e1644a05_normal.jpg
# unknown file extension:  49566447 https://pbs.twimg.com/profile_images/1650251217/kJ8qX6Cd_normal
# unknown file extension:  30378560 https://pbs.twimg.com/profile_images/1798360369/1JrH4Kg6_normal
# unknown file extension:  51709287 https://pbs.twimg.com/profile_images/1466958454/WS6Yz7Tf_normal
# unknown file extension:  24018426 https://pbs.twimg.com/profile_images/2479556274/2l25chkR_normal
# unknown file extension:  27850401 https://pbs.twimg.com/profile_images/2359761987/8pA4n01Y_normal
# Invalid URL '': No scheme supplied. Perhaps you meant http://? 27078336
# unknown file extension:  27393126 https://pbs.twimg.com/profile_images/1779802950/25E1CDE8-EA60-4E45-9330-4A83BB901AAF_normal
# unknown file extension:  68930436 https://pbs.twimg.com/profile_images/1190453234/_____Yosshi-_and_Nitori_normal
# unknown file extension:  43753214 https://pbs.twimg.com/profile_images/1395894730/o94ufV7S_normal
# unknown file extension:  49496992 https://pbs.twimg.com/profile_images/1722970113/DmoKXeaA_normal
# unknown file extension:  20633281 https://pbs.twimg.com/profile_images/1709379899/rhD5Xi9L_normal
# unknown file extension:  34146996 https://pbs.twimg.com/profile_images/1746995402/784EM3b9_normal

# %% [markdown]
# #### combining mixed dataset, genuine dataset and bots dataset to form the final combined dataset

# %%
df_bots = pd.read_csv('bots_scraped.csv')
df_humans = pd.read_csv('final_combined_legit.csv')
df_mix = pd.read_csv('final_combined.csv')

# %%
df_bots['id'] = df_bots['id'].astype(str)
combined_dataset = pd.concat([df_mix, df_humans, df_bots])
combined_dataset = combined_dataset.reset_index(drop = True)
combined_dataset = combined_dataset.drop(columns=combined_dataset.columns[0])
combined_dataset
# Out:
#                id                     name         username  \
# 0      1502026416                      早川援         0918Bask
# 1       191839658                      bio      sweetalkmp3
# 2      1947320929                ❄McKayla❄  1Dniallprincess
# 3       255846106  Giselle | #SaveMacGyver  1GisellePizarro
# 4      1733095801            Nicole Romany    1Nicoleromany
# ...           ...                      ...              ...
# 20289  2396095423         Aldridge Biz Opp   AldridgeBizOpp
# 20290  2396099064          DL Business Opp    DLBusinessOpp
# 20291  2429375022        LF Career Options  LFCareerOptions
# 20292  2429405521                Rick Chou   WestCoastRickC
# 20293  2438666143         CK Small Biz Opp    CKSmallBizOpp
#
#                      created_at  protected  verified                      url  \
# 0      2013-06-11T11:20:35.000Z      False     False                      NaN
# 1      2010-09-17T14:02:10.000Z       True     False                      NaN
# 2      2013-10-08T15:59:30.000Z      False     False                      NaN
# 3      2011-02-22T04:37:34.000Z      False     False  https://t.co/XK9kMS2j8g
# 4      2013-09-05T20:52:02.000Z      False     False                      NaN
# ...                         ...        ...       ...                      ...
# 20289  2014-03-18T11:52:26.000Z      False     False                      NaN
# 20290  2014-03-18T12:03:23.000Z      False     False                      NaN
# 20291  2014-04-05T19:47:10.000Z      False     False                      NaN
# 20292  2014-04-05T20:07:04.000Z      False     False                      NaN
# 20293  2014-04-11T15:08:51.000Z      False     False                      NaN
#
#                                        profile_image_url  \
# 0      https://pbs.twimg.com/profile_images/100439306...
# 1      https://pbs.twimg.com/profile_images/758761054...
# 2      https://pbs.twimg.com/profile_images/100270690...
# 3      https://pbs.twimg.com/profile_images/108000539...
# 4      https://pbs.twimg.com/profile_images/128788084...
# ...                                                  ...
# 20289  https://pbs.twimg.com/profile_images/450760788...
# 20290  https://pbs.twimg.com/profile_images/450782110...
# 20291  https://pbs.twimg.com/profile_images/452536953...
# 20292  https://pbs.twimg.com/profile_images/158212733...
# 20293  https://pbs.twimg.com/profile_images/458780682...
#
#                     location  \
# 0                        NaN
# 1                        NaN
# 2                     Alaska
# 3         Antofagasta, Chile
# 4                        NaN
# ...                      ...
# 20289          North America
# 20290  Growing North America
# 20291  Growing North America
# 20292         Vancouver, BC
# 20293  Growing North America
#
#                                              description  followers_count  \
# 0                                            好きこそ物の上手なれ。              242
# 1                     no longer here I'm @toujoursbeiles             1690
# 2      Live, Young, Wild and Free ♊️ “Attitude Is Eve...              610
# 3      29-year-old Bilingual Management student by da...              102
# 4      Multi Media Journalist/Producer CCNTV6 \nWork ...             1349
# ...                                                  ...              ...
# 20289  We provide Business Resources and Business Con...                7
# 20290  We provide Business Resources and Business Con...              102
# 20291  We help sharp, motivated individuals embrace f...               43
# 20292  Passionate about delivering Customer Experienc...              790
# 20293  We help sharp, motivated individuals embrace f...              158
#
#        following_count  tweet_count  listed_count account_type  \
# 0                  250         3921             1        human
# 1                  791       255840            55        human
# 2                   76        13887             8        human
# 3                   83        94231             8        human
# 4                  382         9999            21        human
# ...                ...          ...           ...          ...
# 20289               20          735             0            1
# 20290              387         2522             6            1
# 20291              101         1302             0            1
# 20292              725         1734             8            1
# 20293              841          135             0            1
#
#        has_profile_image
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 20289               True
# 20290               True
# 20291               True
# 20292               True
# 20293               True
#
# [20294 rows x 16 columns]

# %%
combined_dataset_final = shuffle(combined_dataset)
combined_dataset_final = combined_dataset_final.reset_index(drop = True)
combined_dataset_final
# Out:
#                id              name        username                created_at  \
# 0        18042464      [日向の乙女]ミルミクス          MILMIX  2008-12-11T06:18:59.000Z
# 1        60286377    Tahnee Trotter   tahneetrotter  2009-07-26T11:25:30.000Z
# 2       373791732  Kassandra Garcia   Sassy_Kassy37  2011-09-15T05:49:37.000Z
# 3      2374895658      TonieSabella    TonieSabella  2014-03-06T06:01:31.000Z
# 4        17537004    Mihai Todor 🇺🇦      MihaiTodor  2008-11-21T14:28:51.000Z
# ...           ...               ...             ...                       ...
# 20289    15367428      Paul Urmston     paulurmston  2008-07-09T16:38:23.000Z
# 20290    17006395    Laura Zambelli   laura_trouble  2008-10-27T20:27:57.000Z
# 20291    22130752  The Stag Company  TheStagCompany  2009-02-27T11:31:33.000Z
# 20292    15166188      kelsey lee 🖤     kelseyofzen  2008-06-19T04:57:53.000Z
# 20293  1770131138           𑁍𝚌𝚑𝚎𝚕𝚊𑁍   nosnaheislehc  2013-09-07T19:41:40.000Z
#
#        protected  verified                      url  \
# 0          False     False  https://t.co/AoobuYGh5y
# 1          False     False   http://t.co/P7D9W9j5nT
# 2          False     False                      NaN
# 3          False     False   http://t.co/yakUEMw5xd
# 4          False     False  https://t.co/Ab2jd2vhvV
# ...          ...       ...                      ...
# 20289      False     False                      NaN
# 20290      False     False  https://t.co/lFTff06wEg
# 20291      False     False   http://t.co/GiEeJEGx48
# 20292      False     False                      NaN
# 20293      False     False  https://t.co/3bIqCXqI6Q
#
#                                        profile_image_url         location  \
# 0      https://pbs.twimg.com/profile_images/788469686...               日本
# 1      https://pbs.twimg.com/profile_images/488235175...              NaN
# 2      https://pbs.twimg.com/profile_images/290477377...              NaN
# 3      https://pbs.twimg.com/profile_images/473894199...         Bulgaria
# 4      https://pbs.twimg.com/profile_images/781079151...  Dublin, Ireland
# ...                                                  ...              ...
# 20289  https://pbs.twimg.com/profile_images/161391553...   United Kingdom
# 20290  https://pbs.twimg.com/profile_images/126498263...              NaN
# 20291  https://pbs.twimg.com/profile_images/793413210...     Brighton, UK
# 20292  https://pbs.twimg.com/profile_images/147715462...              NaN
# 20293  https://pbs.twimg.com/profile_images/126725875...                🐝
#
#                                              description  followers_count  \
# 0      テイルズオブシリーズが好きだったり。モバマス貧弱一般人。Splatoon中毒患者。最近はFN...             1959
# 1                                            Get frucked              371
# 2      If you have Motivatoin, Dedication and Faith i...               36
# 3        Ambient/Post Rock music created by Ben Leopard.               30
# 4      Principal Software Engineer interested in comp...             1089
# ...                                                  ...              ...
# 20289                                                NaN               72
# 20290  You heard that i was trouble but you couldn't ...              314
# 20291  #Stagweekends, #stagdos and #stagnights. We do...             2981
# 20292                                    cap ou pas cap?              170
# 20293                               she's in a bad way !              971
#
#        following_count  tweet_count  listed_count account_type  \
# 0                 2708       405158           157        human
# 1                    0        33172            10        human
# 2                    0          548             0            1
# 3                  148           93             1            1
# 4                 2283         9098            34        human
# ...                ...          ...           ...          ...
# 20289               76         4161             1        human
# 20290              107        20915             9        human
# 20291             2523         4991            46        human
# 20292              180         7820             4        human
# 20293              319        64923            21        human
#
#        has_profile_image
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 20289               True
# 20290               True
# 20291               True
# 20292               True
# 20293               True
#
# [20294 rows x 16 columns]

# %%
combined_dataset_final['account_type'] = combined_dataset_final['account_type'].replace(1, 'bot')

# %%
combined_dataset_final
# Out:
#                id              name        username                created_at  \
# 0        18042464      [日向の乙女]ミルミクス          MILMIX  2008-12-11T06:18:59.000Z
# 1        60286377    Tahnee Trotter   tahneetrotter  2009-07-26T11:25:30.000Z
# 2       373791732  Kassandra Garcia   Sassy_Kassy37  2011-09-15T05:49:37.000Z
# 3      2374895658      TonieSabella    TonieSabella  2014-03-06T06:01:31.000Z
# 4        17537004    Mihai Todor 🇺🇦      MihaiTodor  2008-11-21T14:28:51.000Z
# ...           ...               ...             ...                       ...
# 20289    15367428      Paul Urmston     paulurmston  2008-07-09T16:38:23.000Z
# 20290    17006395    Laura Zambelli   laura_trouble  2008-10-27T20:27:57.000Z
# 20291    22130752  The Stag Company  TheStagCompany  2009-02-27T11:31:33.000Z
# 20292    15166188      kelsey lee 🖤     kelseyofzen  2008-06-19T04:57:53.000Z
# 20293  1770131138           𑁍𝚌𝚑𝚎𝚕𝚊𑁍   nosnaheislehc  2013-09-07T19:41:40.000Z
#
#        protected  verified                      url  \
# 0          False     False  https://t.co/AoobuYGh5y
# 1          False     False   http://t.co/P7D9W9j5nT
# 2          False     False                      NaN
# 3          False     False   http://t.co/yakUEMw5xd
# 4          False     False  https://t.co/Ab2jd2vhvV
# ...          ...       ...                      ...
# 20289      False     False                      NaN
# 20290      False     False  https://t.co/lFTff06wEg
# 20291      False     False   http://t.co/GiEeJEGx48
# 20292      False     False                      NaN
# 20293      False     False  https://t.co/3bIqCXqI6Q
#
#                                        profile_image_url         location  \
# 0      https://pbs.twimg.com/profile_images/788469686...               日本
# 1      https://pbs.twimg.com/profile_images/488235175...              NaN
# 2      https://pbs.twimg.com/profile_images/290477377...              NaN
# 3      https://pbs.twimg.com/profile_images/473894199...         Bulgaria
# 4      https://pbs.twimg.com/profile_images/781079151...  Dublin, Ireland
# ...                                                  ...              ...
# 20289  https://pbs.twimg.com/profile_images/161391553...   United Kingdom
# 20290  https://pbs.twimg.com/profile_images/126498263...              NaN
# 20291  https://pbs.twimg.com/profile_images/793413210...     Brighton, UK
# 20292  https://pbs.twimg.com/profile_images/147715462...              NaN
# 20293  https://pbs.twimg.com/profile_images/126725875...                🐝
#
#                                              description  followers_count  \
# 0      テイルズオブシリーズが好きだったり。モバマス貧弱一般人。Splatoon中毒患者。最近はFN...             1959
# 1                                            Get frucked              371
# 2      If you have Motivatoin, Dedication and Faith i...               36
# 3        Ambient/Post Rock music created by Ben Leopard.               30
# 4      Principal Software Engineer interested in comp...             1089
# ...                                                  ...              ...
# 20289                                                NaN               72
# 20290  You heard that i was trouble but you couldn't ...              314
# 20291  #Stagweekends, #stagdos and #stagnights. We do...             2981
# 20292                                    cap ou pas cap?              170
# 20293                               she's in a bad way !              971
#
#        following_count  tweet_count  listed_count account_type  \
# 0                 2708       405158           157        human
# 1                    0        33172            10        human
# 2                    0          548             0          bot
# 3                  148           93             1          bot
# 4                 2283         9098            34        human
# ...                ...          ...           ...          ...
# 20289               76         4161             1        human
# 20290              107        20915             9        human
# 20291             2523         4991            46        human
# 20292              180         7820             4        human
# 20293              319        64923            21        human
#
#        has_profile_image
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 20289               True
# 20290               True
# 20291               True
# 20292               True
# 20293               True
#
# [20294 rows x 16 columns]

# %%
combined_dataset_final[combined_dataset_final['id'].duplicated() == True]
# Out:
#              id                                   name     username  \
# 9760   39927901                        Nadeem Malik 🇵🇰  nadeemmalik
# 12372  43563720                            Boity Thulo        Boity
# 14599  17890482  Denny Cherry - mrdenny@techhub.social      mrdenny
# 15886   9609372                       The Courier-Mail  couriermail
# 19085  21253156                            Katie Shell  Katieshelll
#
#                      created_at  protected  verified                      url  \
# 9760   2009-05-14T04:33:26.000Z      False      True  https://t.co/MsPUgekaPt
# 12372  2009-05-30T17:49:02.000Z      False      True  https://t.co/rXxwHhxIao
# 14599  2008-12-05T04:47:43.000Z      False      True  https://t.co/I7nMJ7vH3p
# 15886  2007-10-22T23:36:14.000Z      False      True   http://t.co/dWMmXIw1tS
# 19085  2009-02-18T23:07:39.000Z      False     False                      NaN
#
#                                        profile_image_url  \
# 9760   https://pbs.twimg.com/profile_images/119097516...
# 12372  https://pbs.twimg.com/profile_images/155437637...
# 14599  https://pbs.twimg.com/profile_images/534778558...
# 15886  https://pbs.twimg.com/profile_images/846231081...
# 19085  https://pbs.twimg.com/profile_images/465262798...
#
#                     location  \
# 9760               ISLAMABAD
# 12372           South Africa
# 14599          Oceanside, CA
# 15886  Queensland, Australia
# 19085    Southern California
#
#                                              description  followers_count  \
# 9760   A Flagship Current Affairs Programme 🇵🇰 Team #...          3138402
# 12372  BOOKINGS: sibo@img-africa.co.za @bt_signature ...          3841139
# 14599  CEO, Microsoft MVP, VMware vExpert, #Azure, #A...            10105
# 15886  Qld's best news source 🌞 Proudly Maroon 💪🏼 \nS...           156635
# 19085  Expeditor/Receptionist and avid book reader. A...              103
#
#        following_count  tweet_count  listed_count account_type  \
# 9760               278         8255          1491        human
# 12372             2733       132104          1648        human
# 14599             1119        89307           494        human
# 15886              991       185128          1470          bot
# 19085              195         4624             4        human
#
#        has_profile_image
# 9760                True
# 12372               True
# 14599               True
# 15886               True
# 19085               True

# %%
combined_dataset_final = combined_dataset_final.drop_duplicates(subset=['id'], keep='first')

# %%
len(combined_dataset_final['id'].unique())
# Out:
# 20289

# %%
combined_dataset_final.to_csv('final_combined_dataset.csv')

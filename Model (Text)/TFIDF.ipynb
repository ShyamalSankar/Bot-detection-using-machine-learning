# %%
#import necessary libraries
import pandas as pd
import numpy as np
import warnings
import nltk

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay, recall_score, precision_score, make_scorer
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.metrics import classification_report, accuracy_score
from sklearn.utils import shuffle

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
import matplotlib.pyplot as plt

import pickle

pd.set_option("display.max_columns", None)
warnings.filterwarnings("ignore")

# %%
#Reading in the dataset
df_tweets_humans = pd.read_csv('human_tweets_processed.csv')
df_tweets_fake = pd.read_csv('bot_tweets_fake_processed.csv')
df_tweets_social = pd.read_csv('bot_tweets_social_processed.csv')

# %%
df_tweets_humans['isBot'] = 0
df_tweets_fake['isBot'] = 1
df_tweets_social['isBot'] = 1

# %%
df_tweets_humans_new = df_tweets_humans.sample(25000).reset_index(drop = True)
df_tweets_fake_new = df_tweets_fake.sample(12500).reset_index(drop = True)
df_tweets_social_new = df_tweets_social.sample(12500).reset_index(drop = True)

# %%
combined_tweets = pd.concat([df_tweets_humans_new, df_tweets_fake_new, df_tweets_social_new]).reset_index(drop = True)
combined_tweets.drop(combined_tweets.filter(regex="Unnamed"),axis=1, inplace=True)
combined_tweets
# Out:
#                        id                                               text  \
# 0      445378199917047810  @AlexJamesFitz @marcoarment Teach a man to Phi...
# 1      504364795080867840     Newport 100s last so long that's why i love em
# 2      513459117030002688  cunliffe pls step down and let labour re-inven...
# 3      593239621905047552  @harry_stylesYou've done so so much for methat...
# 4      365003680128708608  RT @donttrythis: Walter White, you have some c...
# ...                   ...                                                ...
# 49995  217723693193904130      Check out our E-Boutique Store for the Ladies
# 49996   88331881086586880            @ruthaprelia @arini_dwi Happy Birthday!
# 49997  306737245128368129  o´¯`❄.¸(░)`O.¸¸.¸.o´¯`❄.¸(░)`O.❄。¨¯`*✲ ´*。.❄¨¯...
# 49998          5260113690       @st3phy890527 definitely! har har har! RAWR!
# 49999  266573583579504640    followbackWant a #followback? just follow me :L
#
#                                                   source      user_id  \
# 0      <a href="http://tapbots.com/software/tweetbot/...   12287842.0
# 1      <a href="http://twitter.com/download/android" ...  601401812.0
# 2      <a href="https://about.twitter.com/products/tw...  595827319.0
# 3      <a href="https://about.twitter.com/products/tw...  219845841.0
# 4      <a href="http://twitter.com/download/iphone" r...  186855547.0
# ...                                                  ...          ...
# 49995                                                web  619305569.0
# 49996                                                web  242186430.0
# 49997                                                web  616220039.0
# 49998  <a href="http://www.tweetdeck.com/" rel="nofol...   72835654.0
# 49999                                                web  622589126.0
#
#        retweeted_status_id  retweet_count  reply_count  favorite_count  \
# 0             0.000000e+00            0.0          0.0             0.0
# 1             0.000000e+00            0.0          0.0             0.0
# 2             0.000000e+00            0.0          0.0             0.0
# 3             0.000000e+00            1.0          0.0             0.0
# 4             3.648066e+17          211.0          0.0             0.0
# ...                    ...            ...          ...             ...
# 49995                  NaN            0.0          0.0             0.0
# 49996                  NaN            0.0          1.0             1.0
# 49997                  NaN            0.0          0.0             0.0
# 49998                  NaN            0.0          0.0             0.0
# 49999                  NaN            0.0          0.0             0.0
#
#        num_hashtags  num_urls  num_mentions                      created_at  \
# 0               0.0       0.0           2.0  Mon Mar 17 01:56:52 +0000 2014
# 1               0.0       0.0           0.0  Tue Aug 26 20:28:32 +0000 2014
# 2               0.0       0.0           0.0  Sat Sep 20 22:46:07 +0000 2014
# 3               0.0       1.0           1.0  Wed Apr 29 02:25:22 +0000 2015
# 4               0.0       1.0           5.0  Wed Aug 07 06:57:13 +0000 2013
# ...             ...       ...           ...                             ...
# 49995           0.0       0.0           0.0  Tue Jun 26 20:59:08 +0000 2012
# 49996           0.0       0.0           2.0  Tue Jul 05 19:42:16 +0000 2011
# 49997           0.0       0.0           0.0  Wed Feb 27 12:07:12 +0000 2013
# 49998           0.0       0.0           0.0  Thu Oct 29 14:39:44 +0000 2009
# 49999           1.0       0.0           0.0  Thu Nov 08 16:11:09 +0000 2012
#
#        bot                                       cleaned_text  isBot
# 0        0  __user_mention__ __user_mention__ Teach a man ...      0
# 1        0     Newport 100s last so long that's why i love em      0
# 2        0  cunliffe pls step down and let labour re-inven...      0
# 3        0  __user_mention__ done so so much for methats w...      0
# 4        0  RT __user_mention__ Walter White, you have som...      0
# ...    ...                                                ...    ...
# 49995    1      Check out our E-Boutique Store for the Ladies      1
# 49996    1  __user_mention__ __user_mention__ Happy Birthday!      1
# 49997    1  o´¯`❄.¸(░)`O.¸¸.¸.o´¯`❄.¸(░)`O.❄。¨¯`*✲ ´*。.❄¨¯...      1
# 49998    1    __user_mention__ definitely! har har har! RAWR!      1
# 49999    1     followbackWant a __hashtag__ just follow me :L      1
#
# [50000 rows x 15 columns]

# %%
combined_tweets_final = shuffle(combined_tweets)
combined_tweets_final = combined_tweets_final.reset_index(drop = True)
combined_tweets_final
# Out:
#                        id                                               text  \
# 0      578732050921865216  Whoo, go get get it, Olivia! #ScandalABC Oh, d...
# 1      570955971486482432  RT @purpleprism: [MPD/직캠] 150226 Congratulatio...
# 2      581606081895522304  @cnrsocial2 @socialsensing All of Cairo did, a...
# 3      488872386746261505  @MichelleFaithT thanks but her mom and dad are...
# 4      268612298204123136  "To achieve greatness, start where you are, us...
# ...                   ...                                                ...
# 49995  406753071054598144                         ... 24 days till Christmas
# 49996  593286877257584640  @harry_stylesYou've done so so much for methat...
# 49997  164197153051394048                     Join @lovemiyake giveaway! :DD
# 49998  445583842653773824  I posted a new photo to Facebook http://t.co/Z...
# 49999  268496290013388801  Enough said! RT @thinkprogress: Pat Robertson ...
#
#                                                   source       user_id  \
# 0      <a href="https://twitter.com/download/android"...  1.780163e+07
# 1      <a href="http://twitter.com/download/android" ...  2.065326e+08
# 2      <a href="https://about.twitter.com/products/tw...  1.694767e+08
# 3      <a href="http://twitter.com/download/iphone" r...  2.240095e+09
# 4                                                    web  6.162287e+08
# ...                                                  ...           ...
# 49995  <a href="http://twitter.com/download/iphone" r...  1.690357e+08
# 49996  <a href="https://twitter.com/download/android"...  2.198458e+08
# 49997                                                web  8.329319e+07
# 49998  <a href="http://www.facebook.com/twitter" rel=...  1.480228e+08
# 49999  <a href="http://www.handmark.com" rel="nofollo...  1.532866e+07
#
#        retweeted_status_id  retweet_count  reply_count  favorite_count  \
# 0             0.000000e+00            0.0          0.0             0.0
# 1             5.709108e+17           21.0          0.0             0.0
# 2             0.000000e+00            0.0          0.0             1.0
# 3             0.000000e+00            0.0          0.0             0.0
# 4                      NaN            0.0          0.0             0.0
# ...                    ...            ...          ...             ...
# 49995         0.000000e+00            0.0          0.0             0.0
# 49996         0.000000e+00            1.0          0.0             0.0
# 49997                  NaN            0.0          0.0             0.0
# 49998         0.000000e+00            0.0          0.0             0.0
# 49999         0.000000e+00            0.0          0.0             0.0
#
#        num_hashtags  num_urls  num_mentions                      created_at  \
# 0               1.0       0.0           0.0  Fri Mar 20 01:37:27 +0000 2015
# 1               0.0       1.0           1.0  Thu Feb 26 14:38:06 +0000 2015
# 2               0.0       0.0           2.0  Fri Mar 27 23:57:50 +0000 2015
# 3               0.0       0.0           0.0  Tue Jul 15 02:27:14 +0000 2014
# 4               0.0       0.0           0.0  Wed Nov 14 07:12:17 +0000 2012
# ...             ...       ...           ...                             ...
# 49995           0.0       0.0           0.0  Sat Nov 30 11:54:23 +0000 2013
# 49996           0.0       1.0           1.0  Wed Apr 29 05:33:08 +0000 2015
# 49997           0.0       0.0           0.0  Tue Jan 31 04:03:46 +0000 2012
# 49998           0.0       1.0           0.0  Mon Mar 17 15:34:01 +0000 2014
# 49999           0.0       1.0           1.0  Tue Nov 13 23:31:18 +0000 2012
#
#        bot                                       cleaned_text  isBot
# 0        0  Whoo, go get get it, Olivia! __hashtag__ Oh, d...      0
# 1        0  RT __user_mention__ [MPD/직캠] 150226 Congratula...      0
# 2        0  __user_mention__ __user_mention__ All of Cairo...      0
# 3        0  __user_mention__ thanks but her mom and dad ar...      0
# 4        1  "To achieve greatness, start where you are, us...      1
# ...    ...                                                ...    ...
# 49995    0                         ... 24 days till Christmas      0
# 49996    0  __user_mention__ done so so much for methats w...      0
# 49997    1                Join __user_mention__ giveaway! :DD      1
# 49998    0                  I posted a new photo to Facebook       0
# 49999    0  Enough said! RT __user_mention__ Pat Robertson...      0
#
# [50000 rows x 15 columns]

# %%
combined_tweets_final.to_csv('tweets_dataset_allcols.csv', index = False)

# %%
combined_tweets_new = combined_tweets_final[['cleaned_text', 'isBot']]
combined_tweets_new
# Out:
#                                             cleaned_text  isBot
# 0      Whoo, go get get it, Olivia! __hashtag__ Oh, d...      0
# 1      RT __user_mention__ [MPD/직캠] 150226 Congratula...      0
# 2      __user_mention__ __user_mention__ All of Cairo...      0
# 3      __user_mention__ thanks but her mom and dad ar...      0
# 4      "To achieve greatness, start where you are, us...      1
# ...                                                  ...    ...
# 49995                         ... 24 days till Christmas      0
# 49996  __user_mention__ done so so much for methats w...      0
# 49997                Join __user_mention__ giveaway! :DD      1
# 49998                  I posted a new photo to Facebook       0
# 49999  Enough said! RT __user_mention__ Pat Robertson...      0
#
# [50000 rows x 2 columns]

# %%
combined_tweets_new['tokenized'] = combined_tweets_new['cleaned_text'].apply(word_tokenize)

# %%
stop = list(stopwords.words('english'))
contextual_stop = ['day','new','one', 'time','need', "__user_mention__", "__hashtag__"]
lemmatizer = WordNetLemmatizer()

# %%
#Removed stop words
combined_tweets_new['processed_data'] = combined_tweets_new.tokenized.apply(lambda x: [word.casefold() for word in x if word.casefold() not in stop
                                                                    and word not in contextual_stop])
#lemmatize the words
combined_tweets_new['processed_data'] = combined_tweets_new.processed_data.apply(lambda x:[lemmatizer.lemmatize(word) for word in x])

combined_tweets_new['sentence'] = combined_tweets_new['processed_data'].apply(lambda x : " ".join(x))
#Change the sentence to lower case
combined_tweets_new['sentence'] = combined_tweets_new['sentence'].str.lower()

# %%
combined_tweets_new.to_csv('tweets_dataset_processed.csv', index = False)

# %%
combined_tweets_new['isBot'].value_counts()
# Out:
# 0    25000
# 1    25000
# Name: isBot, dtype: int64

# %% [markdown]
# we can consider TfIdf vectors, which could potentially identify rare but useful words that serve as useful features for classification

# %%
dataset = pd.read_csv('tweets_dataset_processed.csv')
dataset
# Out:
#                                             cleaned_text  isBot  \
# 0      Whoo, go get get it, Olivia! __hashtag__ Oh, d...      0
# 1      RT __user_mention__ [MPD/직캠] 150226 Congratula...      0
# 2      __user_mention__ __user_mention__ All of Cairo...      0
# 3      __user_mention__ thanks but her mom and dad ar...      0
# 4      "To achieve greatness, start where you are, us...      1
# ...                                                  ...    ...
# 49995                         ... 24 days till Christmas      0
# 49996  __user_mention__ done so so much for methats w...      0
# 49997                Join __user_mention__ giveaway! :DD      1
# 49998                  I posted a new photo to Facebook       0
# 49999  Enough said! RT __user_mention__ Pat Robertson...      0
#
#                                                tokenized  \
# 0      ['Whoo', ',', 'go', 'get', 'get', 'it', ',', '...
# 1      ['RT', '__user_mention__', '[', 'MPD/직캠', ']',...
# 2      ['__user_mention__', '__user_mention__', 'All'...
# 3      ['__user_mention__', 'thanks', 'but', 'her', '...
# 4      ['``', 'To', 'achieve', 'greatness', ',', 'sta...
# ...                                                  ...
# 49995         ['...', '24', 'days', 'till', 'Christmas']
# 49996  ['__user_mention__', 'done', 'so', 'so', 'much...
# 49997  ['Join', '__user_mention__', 'giveaway', '!', ...
# 49998  ['I', 'posted', 'a', 'new', 'photo', 'to', 'Fa...
# 49999  ['Enough', 'said', '!', 'RT', '__user_mention_...
#
#                                           processed_data  \
# 0      ['whoo', ',', 'go', 'get', 'get', ',', 'olivia...
# 1      ['rt', '[', 'mpd/직캠', ']', '150226', 'congratu...
# 2                ['cairo', ',', 'yes', 'fine', ':', ')']
# 3      ['thanks', 'mom', 'dad', 'home', "'m", 'way', ...
# 4      ['``', 'achieve', 'greatness', ',', 'start', '...
# ...                                                  ...
# 49995          ['...', '24', 'day', 'till', 'christmas']
# 49996  ['done', 'much', 'methats', 'got', 'tattoo', '...
# 49997               ['join', 'giveaway', '!', ':', 'dd']
# 49998                    ['posted', 'photo', 'facebook']
# 49999  ['enough', 'said', '!', 'rt', 'pat', 'robertso...
#
#                                                 sentence
# 0      whoo , go get get , olivia ! oh , damn flashba...
# 1      rt [ mpd/직캠 ] 150226 congratulation 4minute~ !...
# 2                                   cairo , yes fine : )
# 3              thanks mom dad home 'm way home already .
# 4      `` achieve greatness , start , use , . '' -- a...
# ...                                                  ...
# 49995                          ... 24 day till christmas
# 49996  done much methats got tattoo ! hope see & amp ...
# 49997                               join giveaway ! : dd
# 49998                              posted photo facebook
# 49999  enough said ! rt pat robertson excuse petraeus...
#
# [50000 rows x 5 columns]

# %%
#using tfidf vectors
tfidf_vectorizer = TfidfVectorizer(max_df = 0.5, min_df = 10)
#Create an array that contains the BOW representation of each tweet
tfidf_bow_array  = tfidf_vectorizer.fit_transform(dataset['sentence'].values.astype(str))
# #Converting the result into a pandas dataframe
tfidf_bow = pd.DataFrame(tfidf_bow_array.toarray(), columns = tfidf_vectorizer.get_feature_names_out())

# %%
tfidf_bow.shape
# Out:
# (50000, 4368)

# %%
#Next, treat the BOW vectors as features and split the data into training and testing sets
X = tfidf_bow
y = dataset['isBot']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# #### Logistic Regression TFIDF

# %%
# %%time

model_log_reg_tfidf = LogisticRegression()

logreg_tfidf_model = model_log_reg_tfidf.fit(X_train, y_train)
# Out:
# CPU times: user 51.7 s, sys: 1.1 s, total: 52.8 s
# Wall time: 16.8 s

# %%
y_pred = logreg_tfidf_model.predict(X_test)

# Error Metrics
accuracy = metrics.accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
lg_loss = metrics.log_loss(y_test, y_pred)
print(f'Log Loss: {lg_loss}')
roc_auc = metrics.roc_auc_score(y_test, y_pred)
print(f'ROC AUC: {roc_auc}')
f1_score = metrics.f1_score(y_test, y_pred)
print(f'F1-score: {f1_score}')
precision = metrics.precision_score(y_test, y_pred)
print(f'Precision: {precision}')
recall = metrics.recall_score(y_test, y_pred)
print(f'Recall: {recall}')
report = metrics.classification_report(y_test, y_pred)
print(f'Classification Report: \n {report}')
# Out:
# Accuracy: 0.6839
# Log Loss: 11.393398836299932
# ROC AUC: 0.683804922162403
# F1-score: 0.6734841441999794
# Precision: 0.6940600383223334
# Recall: 0.6540930979133226
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69      5016
#            1       0.69      0.65      0.67      4984
#
#     accuracy                           0.68     10000
#    macro avg       0.68      0.68      0.68     10000
# weighted avg       0.68      0.68      0.68     10000

# %% [markdown]
# #### Random Forest TFIDF

# %%
# %%time

model_rf_tfidf = RandomForestClassifier()

rf_tfidf_model = model_rf_tfidf.fit(X_train, y_train)
# Out:
# CPU times: user 18min 37s, sys: 15 s, total: 18min 52s
# Wall time: 20min 5s

# %%
y_pred = rf_tfidf_model.predict(X_test)

# Error Metrics
accuracy = metrics.accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
lg_loss = metrics.log_loss(y_test, y_pred)
print(f'Log Loss: {lg_loss}')
roc_auc = metrics.roc_auc_score(y_test, y_pred)
print(f'ROC AUC: {roc_auc}')
f1_score = metrics.f1_score(y_test, y_pred)
print(f'F1-score: {f1_score}')
precision = metrics.precision_score(y_test, y_pred)
print(f'Precision: {precision}')
recall = metrics.recall_score(y_test, y_pred)
print(f'Recall: {recall}')
report = metrics.classification_report(y_test, y_pred)
print(f'Classification Report: \n {report}')
# Out:
# Accuracy: 0.7435
# Log Loss: 9.24519709430855
# ROC AUC: 0.7434868133049681
# F1-score: 0.7418218419728232
# Precision: 0.7442940820036357
# Recall: 0.7393659711075441
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.75      0.75      5016
#            1       0.74      0.74      0.74      4984
#
#     accuracy                           0.74     10000
#    macro avg       0.74      0.74      0.74     10000
# weighted avg       0.74      0.74      0.74     10000

# %% [markdown]
# ## Import Packages and Reading of Data

# %%
import re
import demoji
import emoji
import warnings
# from google.colab import drive
# drive.mount('/content/gdrive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from scipy.stats import skew
from datetime import datetime
from datetime import date
from collections import OrderedDict
from sklearn.base import BaseEstimator, TransformerMixin
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler

from bs4 import BeautifulSoup

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %%
df_tweets = pd.read_csv("others_dataset.csv")
df_celeb = pd.read_csv("celeb_crawled.csv")
df_bot = pd.read_csv("bots_crawled.csv")

# %%
df_tweets
# Out:
#                        id                 name         username  \
# 0      787405734442958848  The Best In Dumbest  best_in_dumbest
# 1      796216118331310080             CJ Rubin     CJRubinPhoto
# 2      875949740503859204          🔥SVGE GENT🔥         SVGEGENT
# 3      756119643622735875      Danielle Tinker      TinkTinkEDU
# 4               464781334       Joleon Lescott    JoleonLescott
# ...                   ...                  ...              ...
# 35693            91583544           Nick Adams   NickAdamsinUSA
# 35694           236549178             Flavinha         Flavi_mf
# 35695           587035713     Health Conscious   HealthMovement
# 35696          3259069508       Michael Mowery         MikeLBWB
# 35697           524121160           차학연 VIXX_N        CHA_NNNNN
#
#                      created_at protected verified                 location  \
# 0      2016-10-15T21:32:11.000Z     False    False                      NaN
# 1      2016-11-09T05:01:30.000Z     False    False            United States
# 2      2017-06-17T05:34:27.000Z     False    False                      NaN
# 3      2016-07-21T13:32:25.000Z     False    False           Birmingham, AL
# 4      2012-01-15T16:32:35.000Z     False     True  England, United Kingdom
# ...                         ...       ...      ...                      ...
# 35693  2009-11-21T14:39:59.000Z     False     True            United States
# 35694  2011-01-10T21:06:55.000Z     False    False                 Cruzeiro
# 35695  2012-05-21T23:04:09.000Z     False    False                      NaN
# 35696  2015-06-28T16:19:18.000Z     False    False                      NaN
# 35697  2012-03-14T07:48:21.000Z     False     True                 별빛이 있는 곳
#
#                                              description  followers_count  \
# 0      Blame @MoistHorse, Inspired by @MakingInvisibl...           1997.0
# 1      Photographing the American West since 1980. I ...            785.0
# 2      𝖙𝖍𝖊 𝖘𝖆𝖛𝖆𝖌𝖊 𝖌𝖊𝖓𝖙𝖑𝖊𝖒𝖆𝖓                          ...            243.0
# 3                  Wife.Godmother.Friend.Feline Fanatic!            749.0
# 4      England U21 Assistant Coach | @pumafootball Am...         737048.0
# ...                                                  ...              ...
# 35693  Best selling author endorsed by President Trum...         367523.0
# 35694  Menina, moleca, cheia de sonhos, metas, objeti...             14.0
# 35695  Healthcare today leaves us fearful, distracted...            395.0
# 35696                                                NaN            159.0
# 35697                                                NaN         803247.0
#
#        following_count  tweet_count account_type                      url
# 0                  5.0      17090.0          bot  https://t.co/FpAstfF67l
# 1                829.0        251.0        human  https://t.co/rdCgm9pPmh
# 2               1232.0       1469.0        human  https://t.co/lB9hMnHKKq
# 3                838.0       2518.0        human  https://t.co/Xs1wVy0Aox
# 4                128.0       4739.0        human  https://t.co/UMFSFtxE0V
# ...                ...          ...          ...                      ...
# 35693          17291.0      24084.0        human                      NaN
# 35694              0.0        238.0        human  https://t.co/lzjbS0mmVE
# 35695            492.0      21437.0          bot  https://t.co/7n2oZIOm0D
# 35696            618.0       3021.0        human                      NaN
# 35697              7.0       3159.0        human  https://t.co/kfFSga83RW
#
# [35698 rows x 13 columns]

# %% [markdown]
# ## ETL

# %%
def url_text(df):
    pattern = r'(https?:\/\/(?:www\.)?[-a-zA-Z0-9@:%._+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}[-a-zA-Z0-9()@:%_+.~#?&/=]*)' 
    df['url'] = df["uncleaned_text"].str.extract(pattern, expand=True)
    return df

def username(df):
    special_char = re.compile('[@_!#$%^&*()<>?/\|}{~:]')
    df["un_no_of_char"] = df["username"].apply(lambda x: len(str(x)))
    df["un_special_char"] = df["username"].apply(lambda x: special_char.search(str(x)) != None)
    df["un_uppercase"] = df["username"].apply(lambda x: bool(re.match(r'\w*[A-Z]\w*', str(x))))
    return df

def name(df):
    special_char = re.compile('[@_!#$%^&*()<>?/\|}{~:]')
    df["name_no_of_char"] = df["name"].apply(lambda x: len(str(x)))
    df["name_special_char"] = df["name"].apply(lambda x: special_char.search(str(x)) != None)
    df["name_uppercase"] = df["name"].apply(lambda x: bool(re.match(r'\w*[A-Z]\w*', str(x))))
    return df

def description(df):
    #user_tags = re.compile('[@]')
    #hastags = re.compile('[#]')
    user_tags = r'\B@\w*[a-zA-Z]*\w*'
    hashtags = r'\B#\w*[a-zA-Z]+\w*'
    links = r'(https?:\/\/(?:www\.)?[-a-zA-Z0-9@:%._+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}[-a-zA-Z0-9()@:%_+.~#?&/=]*)'
    df["des_no_of_usertags"] = df["description"].apply(lambda x: len(re.findall(user_tags, str(x)))) #str(x).count('@'))
    df["des_no_of_hashtags"] = df["description"].apply(lambda x: len(re.findall(hashtags, str(x)))) #str(x).count('#'))
    df["des_external_links"] = df["description"].apply(lambda x: re.findall(links, str(x)) != [])
    df["has_description"] = ~df_tweets["description"].isna() 
    return df

def location(df):
    df["location"] = ~df_tweets["location"].isna() # false = location is NaN; true = has location
    return df
  
def time(df):
    # df["created_time"] = df["created_at"].apply(lambda x : datetime.strptime(x, '%Y-%m-%dT%H:%M:%S.%f%z').date())
    # d1 = date(2022, 10, 8) # date we extracted these data 
    df["account_age_in_days"] = df["created_at"].apply(lambda x : (date(2022, 10, 8) - datetime.strptime(x, '%Y-%m-%dT%H:%M:%S.%f%z').date()).days)
    df["average_tweets_per_day"] = df["tweet_count"]/df["account_age_in_days"]
    return df

def time_bot(df):
    # df["created_time"] = df["created_at"].apply(lambda x : datetime.strptime(x, '%Y-%m-%dT%H:%M:%S.%f%z').date())
    # d1 = date(2022, 10, 8) # date we extracted these data 
    df["account_age_in_days"] = df["created_at"].apply(lambda x : (date(2022, 11, 15) - datetime.strptime(x, '%Y-%m-%dT%H:%M:%S.%f%z').date()).days)
    df["average_tweets_per_day"] = df["tweet_count"]/df["account_age_in_days"]
    return df

def follow_count(df):
    df["followers_following_count"] = df["followers_count"] * df["following_count"]
    return df

def get_year(date):
    return datetime.strptime(date, '%Y-%m-%dT%H:%M:%S.%f%z').year

def get_month(date):
    return datetime.strptime(date, '%Y-%m-%dT%H:%M:%S.%f%z').strftime('%b')

def get_weekday(date):
    return datetime.strptime(date, '%Y-%m-%dT%H:%M:%S.%f%z').strftime('%a')

class DateTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        year = X.apply(get_year).rename('year')
        month = pd.get_dummies(X.apply(get_month))
        day = pd.get_dummies(X.apply(get_weekday))
        return pd.concat([year, month, day], axis=1) 

def account_type(df):
    df["isFraud"] = df["account_type"].apply(lambda x : 1 if x == 'bot' else 0)
    return df

def convert_PV(variable):
    if variable == 'True':
        return True
    if variable == 'False':
        return False
    if variable == '0.0':
        return False
    if variable == '1.0':
        return True
    return variable

def convert_TF(variable):
    var = 1 if variable == True else 0
    return var

# %%
df_tweets = account_type(df_tweets)
df_tweets = username(df_tweets)
df_tweets = name(df_tweets)
df_tweets = description(df_tweets)
df_tweets = location(df_tweets)
df_tweets = time(df_tweets)
df_tweets = follow_count(df_tweets)

pv_var = ["verified", "protected"]

for var in pv_var:
    df_tweets[var] = df_tweets[var].apply(convert_PV)

boolean_var = ["verified", "location", "un_special_char", "un_uppercase", 
               "name_special_char", "name_uppercase", "des_external_links", 
               "has_description", "protected"]

for var in boolean_var:
    df_tweets[var] = df_tweets[var].apply(convert_TF)
    
int_var = ["followers_count", "following_count", "tweet_count"]

for var in int_var:
    df_tweets[var] = df_tweets[var].astype(int)

# %%
df_celeb = account_type(df_celeb)
df_celeb = username(df_celeb)
df_celeb = name(df_celeb)
df_celeb = description(df_celeb)
df_celeb = location(df_celeb)
df_celeb = time(df_celeb)

pv_var = ["verified", "protected"]

for var in pv_var:
    df_celeb[var] = df_celeb[var].apply(convert_PV)

boolean_var = ["verified", "location", "un_special_char", "un_uppercase", 
               "name_special_char", "name_uppercase", "des_external_links", 
               "has_description", "protected"]

for var in boolean_var:
    df_celeb[var] = df_celeb[var].apply(convert_TF)
    
int_var = ["followers_count", "following_count", "tweet_count"]

for var in int_var:
    df_celeb[var] = df_celeb[var].astype(int)

# %%
df_bot["account_type"] = "bot"
df_bot = account_type(df_bot)
df_bot = username(df_bot)
df_bot = name(df_bot)
df_bot = description(df_bot)
df_bot = location(df_bot)
df_bot = time_bot(df_bot)

boolean_var = ["verified", "location", "un_special_char", "un_uppercase", 
               "name_special_char", "name_uppercase", "des_external_links", 
               "has_description", "protected"]

for var in boolean_var:
    df_bot[var] = df_bot[var].apply(convert_TF)
    
int_var = ["followers_count", "following_count", "tweet_count"]

for var in int_var:
    df_bot[var] = df_bot[var].astype(int)

# %%
new_df_tweets = df_tweets.drop(columns=["id", "created_at", "name", "username", "description", "url"])
new_df_celeb = df_celeb.drop(columns=["id", "created_at", "name", "username", "description", "Unnamed: 0", "account_type", "average_tweets_per_day"])
new_df_bot = df_bot.drop(columns=["id", "created_at", "name", "username", "description", "Unnamed: 0", "account_type", "average_tweets_per_day"])

# %%
saved_df_tweets = new_df_tweets.drop(columns=["account_type"])

# %%
saved_df_tweets
# Out:
#        protected  verified  location  followers_count  following_count  \
# 0              0         0         0             1997                5
# 1              0         0         1              785              829
# 2              0         0         0              243             1232
# 3              0         0         1              749              838
# 4              0         1         1           737048              128
# ...          ...       ...       ...              ...              ...
# 35693          0         1         1           367523            17291
# 35694          0         0         1               14                0
# 35695          0         0         0              395              492
# 35696          0         0         0              159              618
# 35697          0         1         1           803247                7
#
#        tweet_count  isFraud  un_no_of_char  un_special_char  un_uppercase  \
# 0            17090        1             15                1             0
# 1              251        0             12                0             1
# 2             1469        0              8                0             1
# 3             2518        0             11                0             1
# 4             4739        0             13                0             1
# ...            ...      ...            ...              ...           ...
# 35693        24084        0             14                0             1
# 35694          238        0              8                1             1
# 35695        21437        1             14                0             1
# 35696         3021        0              8                0             1
# 35697         3159        0              9                1             1
#
#        name_no_of_char  name_special_char  name_uppercase  des_no_of_usertags  \
# 0                   19                  0               1                   2
# 1                    8                  0               1                   0
# 2                   11                  0               0                   0
# 3                   15                  0               1                   0
# 4                   14                  0               1                   1
# ...                ...                ...             ...                 ...
# 35693               10                  0               1                   2
# 35694                8                  0               1                   0
# 35695               16                  0               1                   0
# 35696               14                  0               1                   0
# 35697               10                  1               0                   0
#
#        des_no_of_hashtags  des_external_links  has_description  \
# 0                       0                   0                1
# 1                       0                   0                1
# 2                       0                   0                1
# 3                       0                   0                1
# 4                       0                   0                1
# ...                   ...                 ...              ...
# 35693                   0                   0                1
# 35694                   0                   0                1
# 35695                   0                   0                1
# 35696                   0                   0                0
# 35697                   0                   0                0
#
#        account_age_in_days  average_tweets_per_day  followers_following_count
# 0                     2184                7.825092               9.985000e+03
# 1                     2159                0.116258               6.507650e+05
# 2                     1939                0.757607               2.993760e+05
# 3                     2270                1.109251               6.276620e+05
# 4                     3919                1.209237               9.434214e+07
# ...                    ...                     ...                        ...
# 35693                 4704                5.119898               6.354840e+09
# 35694                 4289                0.055491               0.000000e+00
# 35695                 3792                5.653217               1.943400e+05
# 35696                 2659                1.136141               9.826200e+04
# 35697                 3860                0.818394               5.622729e+06
#
# [35698 rows x 20 columns]

# %%
saved_df_tweets.describe()
# Out:
#           protected      verified      location  followers_count  \
# count  35698.000000  35698.000000  35698.000000     3.569800e+04
# mean       0.044932      0.204045      0.647627     4.001255e+05
# std        0.207159      0.403008      0.477716     2.612395e+06
# min        0.000000      0.000000      0.000000     0.000000e+00
# 25%        0.000000      0.000000      0.000000     3.500000e+01
# 50%        0.000000      0.000000      1.000000     3.820000e+02
# 75%        0.000000      0.000000      1.000000     1.058400e+04
# max        1.000000      1.000000      1.000000     1.334895e+08
#
#        following_count   tweet_count       isFraud  un_no_of_char  \
# count     3.569800e+04  3.569800e+04  35698.000000   35698.000000
# mean      4.078916e+03  2.365311e+04      0.332316      11.112555
# std       4.630970e+04  7.659224e+04      0.471050       2.650621
# min       0.000000e+00  0.000000e+00      0.000000       2.000000
# 25%       3.100000e+01  1.382000e+03      0.000000       9.000000
# 50%       3.020000e+02  4.608500e+03      0.000000      11.000000
# 75%       9.440000e+02  1.904075e+04      1.000000      13.000000
# max       4.099498e+06  2.935091e+06      1.000000      15.000000
#
#        un_special_char  un_uppercase  name_no_of_char  name_special_char  \
# count     35698.000000  35698.000000     35698.000000       35698.000000
# mean          0.159001      0.496975        12.115861           0.043812
# std           0.365682      0.499998         5.789131           0.204679
# min           0.000000      0.000000         1.000000           0.000000
# 25%           0.000000      0.000000         9.000000           0.000000
# 50%           0.000000      0.000000        12.000000           0.000000
# 75%           0.000000      1.000000        15.000000           0.000000
# max           1.000000      1.000000        50.000000           1.000000
#
#        name_uppercase  des_no_of_usertags  des_no_of_hashtags  \
# count    35698.000000        35698.000000        35698.000000
# mean         0.781921            0.272760            0.252423
# std          0.412947            0.832519            1.010830
# min          0.000000            0.000000            0.000000
# 25%          1.000000            0.000000            0.000000
# 50%          1.000000            0.000000            0.000000
# 75%          1.000000            0.000000            0.000000
# max          1.000000           11.000000           17.000000
#
#        des_external_links  has_description  account_age_in_days  \
# count        35698.000000     35698.000000         35698.000000
# mean             0.105636         0.801866          3812.933218
# std              0.307376         0.398600          1013.805295
# min              0.000000         0.000000          1263.000000
# 25%              0.000000         1.000000          3108.000000
# 50%              0.000000         1.000000          4013.000000
# 75%              0.000000         1.000000          4682.000000
# max              1.000000         1.000000          5939.000000
#
#        average_tweets_per_day  followers_following_count
# count            35698.000000               3.569800e+04
# mean                 6.032200               7.552310e+09
# std                 21.462159               4.695637e+11
# min                  0.000000               0.000000e+00
# 25%                  0.390298               6.852500e+02
# 50%                  1.236860               1.458030e+05
# 75%                  4.779506               1.093506e+07
# max               1224.485190               7.750465e+13

# %%
new_df_celeb
# Out:
#      protected  verified  location  followers_count  following_count  \
# 0            0         1         1        108878036              245
# 1            0         1         1        113825417           281733
# 2            0         1         1         91736362                0
# 3            0         1         1        107130421              982
# 4            0         1         1         84952188           117031
# ..         ...       ...       ...              ...              ...
# 917          0         0         1             2997             1167
# 918          0         0         1            65723             1482
# 919          0         0         1            16650             1022
# 920          0         0         1            44241            28736
# 921          0         0         1            41776            30709
#
#      tweet_count  isFraud  un_no_of_char  un_special_char  un_uppercase  \
# 0          11778        0              9                0             0
# 1          31332        0             12                0             0
# 2            742        0             13                0             0
# 3          10656        0              7                0             0
# 4           9954        0              8                0             0
# ..           ...      ...            ...              ...           ...
# 917        21969        0             14                0             0
# 918        10392        0             13                0             0
# 919        29751        0             11                0             0
# 920       137224        0             15                0             1
# 921       165383        0             14                1             1
#
#      name_no_of_char  name_special_char  name_uppercase  des_no_of_usertags  \
# 0                 10                  0               1                   0
# 1                 13                  0               1                   0
# 2                 12                  0               1                   0
# 3                  7                  0               1                   0
# 4                  9                  0               1                   1
# ..               ...                ...             ...                 ...
# 917               15                  0               1                   0
# 918               16                  0               1                   0
# 919               12                  0               1                   1
# 920               18                  0               1                   0
# 921               15                  0               1                   0
#
#      des_no_of_hashtags  des_external_links  has_description  \
# 0                     0                   0                1
# 1                     0                   0                1
# 2                     0                   0                1
# 3                     0                   0                1
# 4                     0                   1                1
# ..                  ...                 ...              ...
# 917                   0                   0                1
# 918                   0                   0                1
# 919                   0                   0                1
# 920                   7                   0                1
# 921                   3                   0                1
#
#      account_age_in_days
# 0                   4978
# 1                   4942
# 2                   5054
# 3                   4754
# 4                   5309
# ..                   ...
# 917                 4835
# 918                 5088
# 919                 5672
# 920                 3656
# 921                 3631
#
# [922 rows x 18 columns]

# %%
new_df_celeb.describe()
# Out:
#         protected    verified  location  followers_count  following_count  \
# count  922.000000  922.000000     922.0     9.220000e+02     9.220000e+02
# mean     0.003254    0.917570       1.0     9.014784e+06     1.136997e+04
# std      0.056980    0.275167       0.0     1.262336e+07     1.469657e+05
# min      0.000000    0.000000       1.0     0.000000e+00     0.000000e+00
# 25%      0.000000    1.000000       1.0     3.327100e+06     1.600000e+02
# 50%      0.000000    1.000000       1.0     5.130928e+06     4.885000e+02
# 75%      0.000000    1.000000       1.0     9.284552e+06     1.167000e+03
# max      1.000000    1.000000       1.0     1.151700e+08     4.081373e+06
#
#          tweet_count  isFraud  un_no_of_char  un_special_char  un_uppercase  \
# count     922.000000    922.0     922.000000       922.000000    922.000000
# mean    22047.852495      0.0      10.682213         0.073753      0.518438
# std     35081.847645      0.0       2.676128         0.261510      0.499931
# min         0.000000      0.0       3.000000         0.000000      0.000000
# 25%      4647.750000      0.0       9.000000         0.000000      0.000000
# 50%     11447.500000      0.0      11.000000         0.000000      1.000000
# 75%     24728.000000      0.0      13.000000         0.000000      1.000000
# max    434856.000000      0.0      15.000000         1.000000      1.000000
#
#        name_no_of_char  name_special_char  name_uppercase  des_no_of_usertags  \
# count       922.000000         922.000000      922.000000          922.000000
# mean         12.291757           0.019523        0.889371            0.376356
# std           4.215750           0.138428        0.313842            0.929902
# min           1.000000           0.000000        0.000000            0.000000
# 25%          10.000000           0.000000        1.000000            0.000000
# 50%          12.000000           0.000000        1.000000            0.000000
# 75%          15.000000           0.000000        1.000000            0.000000
# max          48.000000           1.000000        1.000000            9.000000
#
#        des_no_of_hashtags  des_external_links  has_description  \
# count          922.000000          922.000000       922.000000
# mean             0.219089            0.164859         0.818872
# std              1.011199            0.371255         0.385333
# min              0.000000            0.000000         0.000000
# 25%              0.000000            0.000000         1.000000
# 50%              0.000000            0.000000         1.000000
# 75%              0.000000            0.000000         1.000000
# max             17.000000            1.000000         1.000000
#
#        account_age_in_days
# count           922.000000
# mean           4660.584599
# std             489.258228
# min             633.000000
# 25%            4470.750000
# 50%            4806.500000
# 75%            4940.000000
# max            6045.000000

# %%
new_df_bot
# Out:
#      protected  verified  location  followers_count  following_count  \
# 0            0         0         1                0                0
# 1            0         0         1               92              504
# 2            0         0         1              115                0
# 3            0         0         1                0                0
# 4            0         0         1             1529             1417
# ..         ...       ...       ...              ...              ...
# 665          0         0         1              180             1244
# 666          0         0         1              181              333
# 667          0         0         1               16               24
# 668          0         0         1            35530            44283
# 669          0         0         1            29334            27320
#
#      tweet_count  isFraud  un_no_of_char  un_special_char  un_uppercase  \
# 0              7        1              9                0             0
# 1           1188        1              7                0             1
# 2            210        1             15                0             1
# 3             89        1             11                0             1
# 4          40057        1              9                1             1
# ..           ...      ...            ...              ...           ...
# 665           35        1             15                0             1
# 666           95        1             13                1             0
# 667            4        1             15                0             1
# 668       287996        1              8                0             0
# 669        23807        1             15                0             1
#
#      name_no_of_char  name_special_char  name_uppercase  des_no_of_usertags  \
# 0                  3                  0               0                   0
# 1                  2                  0               1                   0
# 2                 12                  0               1                   0
# 3                 12                  0               1                   0
# 4                  5                  0               1                   0
# ..               ...                ...             ...                 ...
# 665               17                  0               1                   0
# 666               12                  1               0                   0
# 667               11                  0               1                   0
# 668               12                  0               1                   0
# 669               47                  1               1                   0
#
#      des_no_of_hashtags  des_external_links  has_description  \
# 0                     0                   0                1
# 1                     0                   0                1
# 2                     6                   0                1
# 3                     0                   0                1
# 4                     0                   0                1
# ..                  ...                 ...              ...
# 665                   1                   0                1
# 666                   0                   0                1
# 667                   0                   0                0
# 668                   1                   0                1
# 669                   0                   1                1
#
#      account_age_in_days
# 0                   4881
# 1                   4838
# 2                   3936
# 3                   3067
# 4                   3614
# ..                   ...
# 665                 1850
# 666                 1848
# 667                 1771
# 668                 3775
# 669                 3479
#
# [670 rows x 18 columns]

# %%
new_df_bot.describe()
# Out:
#         protected    verified  location  followers_count  following_count  \
# count  670.000000  670.000000     670.0     6.700000e+02     6.700000e+02
# mean     0.016418    0.043284       1.0     9.527123e+04     4.553474e+04
# std      0.127171    0.203647       0.0     9.033517e+05     2.153091e+05
# min      0.000000    0.000000       1.0     0.000000e+00     0.000000e+00
# 25%      0.000000    0.000000       1.0     4.000000e+00     0.000000e+00
# 50%      0.000000    0.000000       1.0     4.050000e+01     0.000000e+00
# 75%      0.000000    0.000000       1.0     3.788000e+03     2.422250e+03
# max      1.000000    1.000000       1.0     2.282222e+07     4.078830e+06
#
#          tweet_count  isFraud  un_no_of_char  un_special_char  un_uppercase  \
# count     670.000000    670.0     670.000000       670.000000    670.000000
# mean    15009.846269      1.0      11.204478         0.191045      0.510448
# std     53790.809920      0.0       2.638959         0.393418      0.500264
# min         0.000000      1.0       3.000000         0.000000      0.000000
# 25%        27.000000      1.0       9.000000         0.000000      0.000000
# 50%       126.500000      1.0      11.000000         0.000000      1.000000
# 75%      3443.500000      1.0      13.000000         0.000000      1.000000
# max    648420.000000      1.0      15.000000         1.000000      1.000000
#
#        name_no_of_char  name_special_char  name_uppercase  des_no_of_usertags  \
# count       670.000000         670.000000      670.000000          670.000000
# mean         12.432836           0.056716        0.691045            0.108955
# std           5.824601           0.231473        0.462408            0.452606
# min           1.000000           0.000000        0.000000            0.000000
# 25%           9.000000           0.000000        0.000000            0.000000
# 50%          12.000000           0.000000        1.000000            0.000000
# 75%          15.000000           0.000000        1.000000            0.000000
# max          50.000000           1.000000        1.000000            4.000000
#
#        des_no_of_hashtags  des_external_links  has_description  \
# count          670.000000          670.000000       670.000000
# mean             0.340299            0.102985         0.822388
# std              1.409137            0.304166         0.382471
# min              0.000000            0.000000         0.000000
# 25%              0.000000            0.000000         1.000000
# 50%              0.000000            0.000000         1.000000
# 75%              0.000000            0.000000         1.000000
# max             17.000000            1.000000         1.000000
#
#        account_age_in_days
# count           670.000000
# mean           3537.820896
# std             984.539602
# min             119.000000
# 25%            2984.000000
# 50%            3791.500000
# 75%            4218.500000
# max            5726.000000

# %%
new_df_bot.to_csv("cleaned_bot_dataset.csv", index = False)
new_df_celeb.to_csv("cleaned_celeb_dataset.csv", index = False)

# %% [markdown]
# ## Feature Engineering
# * Standard Scaler
# * Train - Test Split

# %%
numeric_variables = ['followers_count', 'following_count', 'tweet_count', 'un_no_of_char','name_no_of_char', 'des_no_of_usertags', 'des_no_of_hashtags', 'account_age_in_days']

# %%
new_df_bot.to_csv("cleaned_bot_dataset.csv", index = False)
new_df_celeb.to_csv("cleaned_celeb_dataset.csv", index = False)

# %% [markdown]
# ## Exploratory Data Analysis
# * Heatmap
# * Barchart
# * Histogram
# * Boxplot

# %%
# Functions to plot data distributions
def plot_multiple_histograms(data: pd.DataFrame,
                             grouped_col: str,
                             target_col: str,
                             data_labels: dict):
    # Plot
    plt.figure(figsize=(12, 10))
    title = "\n"
    labels: list = list(data_labels.keys())
    for j, i in enumerate(labels):
        x = data.loc[data[grouped_col] == i, target_col]
        mu_x = round(float(np.mean(x)), 3)
        sigma_x = round(float(np.std(x)), 3)
        ax = sns.distplot(x, color=data_labels.get(i), label=i, hist_kws=dict(alpha=.1),
                          kde_kws={'linewidth': 2})
        ax.axvline(mu_x, color=data_labels.get(i), linestyle='--')
        ax.set(xlabel=f"{target_col.title()}", ylabel='Density')
        title += f"Parameters {str(i)}: $G(\mu=$ {mu_x}, $\sigma=$ {sigma_x}) \n"
        ax.set_title(target_col.title() + title)
    plt.legend(title="Account Type")
    plt.grid()
    plt.tight_layout()
    # bg = fig.patch
    # bg.set_facecolor("white")
    # plt.savefig(f'..\\Images\\Histogram\\{target_col}.jpg', facecolor=fig.get_facecolor())
    plt.show()


def plot_multiple_boxplots(data: pd.DataFrame, grouped_col: str, target_col: str,
                           palette: str = "husl"):
    plt.figure(figsize=(12, 10))

    means: dict = data.groupby([grouped_col])[target_col].mean().to_dict(OrderedDict)
    counter: int = 0

    bp = sns.boxplot(x=grouped_col, y=target_col, data=data, palette=palette, order=list(means.keys()))
    bp.set(xlabel='', ylabel=f"{target_col.title()}")
    ax = bp.axes

    for k, v in means.items():
        # every 4th line at the interval of 6 is median line
        # 0 -> p25 1 -> p75 2 -> lower whisker 3 -> upper whisker 4 -> p50 5 -> upper extreme value
        mean = round(v, 2)
        ax.text(
            counter,
            mean,
            f'{mean}',
            ha='center',
            va='center',
            fontweight='bold',
            size=10,
            color='white',
            bbox=dict(facecolor='#445A64'))
        counter += 1
    bp.figure.tight_layout()
    plt.grid()
    # bg = fig.patch
    # bg.set_facecolor("white")
    # plt.savefig(f'..\\Images\\Boxplot\\{target_col}.jpg', facecolor=fig.get_facecolor())
    plt.show()

def add_labels(plot):
    for p in plot.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy()
        plt.text(x+width/2,
                y+height*1.01,
                str(format(int(p.get_height()), ',d')),
                ha='center')

# %%
palette: str = "husl"
grouped: str = "account_type"
default_value: str = "unknown"

def get_labels_colors_from_pandas_column(df: pd.DataFrame, column: str, palette: str):
    data_labels: dict = dict()
    labels: list = df[column].unique().tolist()
    colors: list = sns.color_palette(palette, len(labels))
    data_labels: dict = dict(zip(labels, colors))
    return data_labels

# Retrieve labels and additional parameters to plot figures
data_labels: dict = get_labels_colors_from_pandas_column(
    df=new_df_tweets, column=grouped, palette=palette)

# %% [markdown]
# ### Heatmap

# %%
heatmap_tweets = new_df_tweets[['isFraud', 'verified', 'protected', 'location', 'followers_count', 
                                'following_count', 'tweet_count', 'account_type', 
                                'un_no_of_char', 'un_special_char', 'un_uppercase', 
                                'name_no_of_char', 'name_special_char', 'name_uppercase', 
                                'des_no_of_usertags', 'des_no_of_hashtags', 'des_external_links', 
                                'has_description', 'account_age_in_days', 'followers_following_count', 
                                'average_tweets_per_day']]

# %%
fig, axs = plt.subplots(1,1, figsize=(20,20))
hm = sns.heatmap(round(heatmap_tweets.corr(),2), 
                 ax=axs,           # Axes in which to draw the plot, otherwise use the currently-active Axes.
                 cmap="coolwarm",  # Color Map.
                 #square=True,     # If True, set the Axes aspect to “equal” so each cell will be square-shaped.
                 annot=True, 
                 linewidths=.05)
fig.subplots_adjust(top=0.96)
t = fig.suptitle('Correlation Heatmap', fontsize=18, fontweight='bold')

# %%
saved_df_tweets = saved_df_tweets.drop(columns=["followers_following_count", "average_tweets_per_day"])
saved_df_tweets
# Out:
#        protected  verified  location  followers_count  following_count  \
# 0              0         0         0             1997                5
# 1              0         0         1              785              829
# 2              0         0         0              243             1232
# 3              0         0         1              749              838
# 4              0         1         1           737048              128
# ...          ...       ...       ...              ...              ...
# 35693          0         1         1           367523            17291
# 35694          0         0         1               14                0
# 35695          0         0         0              395              492
# 35696          0         0         0              159              618
# 35697          0         1         1           803247                7
#
#        tweet_count  isFraud  un_no_of_char  un_special_char  un_uppercase  \
# 0            17090        1             15                1             0
# 1              251        0             12                0             1
# 2             1469        0              8                0             1
# 3             2518        0             11                0             1
# 4             4739        0             13                0             1
# ...            ...      ...            ...              ...           ...
# 35693        24084        0             14                0             1
# 35694          238        0              8                1             1
# 35695        21437        1             14                0             1
# 35696         3021        0              8                0             1
# 35697         3159        0              9                1             1
#
#        name_no_of_char  name_special_char  name_uppercase  des_no_of_usertags  \
# 0                   19                  0               1                   2
# 1                    8                  0               1                   0
# 2                   11                  0               0                   0
# 3                   15                  0               1                   0
# 4                   14                  0               1                   1
# ...                ...                ...             ...                 ...
# 35693               10                  0               1                   2
# 35694                8                  0               1                   0
# 35695               16                  0               1                   0
# 35696               14                  0               1                   0
# 35697               10                  1               0                   0
#
#        des_no_of_hashtags  des_external_links  has_description  \
# 0                       0                   0                1
# 1                       0                   0                1
# 2                       0                   0                1
# 3                       0                   0                1
# 4                       0                   0                1
# ...                   ...                 ...              ...
# 35693                   0                   0                1
# 35694                   0                   0                1
# 35695                   0                   0                1
# 35696                   0                   0                0
# 35697                   0                   0                0
#
#        account_age_in_days
# 0                     2184
# 1                     2159
# 2                     1939
# 3                     2270
# 4                     3919
# ...                    ...
# 35693                 4704
# 35694                 4289
# 35695                 3792
# 35696                 2659
# 35697                 3860
#
# [35698 rows x 18 columns]

# %%
saved_df_tweets.describe()
# Out:
#           protected      verified      location  followers_count  \
# count  35698.000000  35698.000000  35698.000000     3.569800e+04
# mean       0.044932      0.204045      0.647627     4.001255e+05
# std        0.207159      0.403008      0.477716     2.612395e+06
# min        0.000000      0.000000      0.000000     0.000000e+00
# 25%        0.000000      0.000000      0.000000     3.500000e+01
# 50%        0.000000      0.000000      1.000000     3.820000e+02
# 75%        0.000000      0.000000      1.000000     1.058400e+04
# max        1.000000      1.000000      1.000000     1.334895e+08
#
#        following_count   tweet_count       isFraud  un_no_of_char  \
# count     3.569800e+04  3.569800e+04  35698.000000   35698.000000
# mean      4.078916e+03  2.365311e+04      0.332316      11.112555
# std       4.630970e+04  7.659224e+04      0.471050       2.650621
# min       0.000000e+00  0.000000e+00      0.000000       2.000000
# 25%       3.100000e+01  1.382000e+03      0.000000       9.000000
# 50%       3.020000e+02  4.608500e+03      0.000000      11.000000
# 75%       9.440000e+02  1.904075e+04      1.000000      13.000000
# max       4.099498e+06  2.935091e+06      1.000000      15.000000
#
#        un_special_char  un_uppercase  name_no_of_char  name_special_char  \
# count     35698.000000  35698.000000     35698.000000       35698.000000
# mean          0.159001      0.496975        12.115861           0.043812
# std           0.365682      0.499998         5.789131           0.204679
# min           0.000000      0.000000         1.000000           0.000000
# 25%           0.000000      0.000000         9.000000           0.000000
# 50%           0.000000      0.000000        12.000000           0.000000
# 75%           0.000000      1.000000        15.000000           0.000000
# max           1.000000      1.000000        50.000000           1.000000
#
#        name_uppercase  des_no_of_usertags  des_no_of_hashtags  \
# count    35698.000000        35698.000000        35698.000000
# mean         0.781921            0.272760            0.252423
# std          0.412947            0.832519            1.010830
# min          0.000000            0.000000            0.000000
# 25%          1.000000            0.000000            0.000000
# 50%          1.000000            0.000000            0.000000
# 75%          1.000000            0.000000            0.000000
# max          1.000000           11.000000           17.000000
#
#        des_external_links  has_description  account_age_in_days
# count        35698.000000     35698.000000         35698.000000
# mean             0.105636         0.801866          3812.933218
# std              0.307376         0.398600          1013.805295
# min              0.000000         0.000000          1263.000000
# 25%              0.000000         1.000000          3108.000000
# 50%              0.000000         1.000000          4013.000000
# 75%              0.000000         1.000000          4682.000000
# max              1.000000         1.000000          5939.000000

# %%
saved_df_tweets.to_csv("cleaned_others_dataset.csv", index = False)

# %%
new_heatmap_tweets = new_df_tweets[['isFraud', 'verified', 'protected', 'location', 'followers_count', 
                                    'following_count', 'tweet_count', 'account_type', 
                                    'un_no_of_char', 'un_special_char', 'un_uppercase', 
                                    'name_no_of_char', 'name_special_char', 'name_uppercase', 
                                    'des_no_of_usertags', 'des_no_of_hashtags', 'des_external_links', 
                                    'has_description', 'account_age_in_days']]

# %%
fig, axs = plt.subplots(1,1, figsize=(20,20))
hm = sns.heatmap(round(new_heatmap_tweets.corr(),2), 
                 ax=axs,           # Axes in which to draw the plot, otherwise use the currently-active Axes.
                 cmap="coolwarm",  # Color Map.
                 #square=True,     # If True, set the Axes aspect to “equal” so each cell will be square-shaped.
                 annot=True, 
                 linewidths=.05)
fig.subplots_adjust(top=0.96)
t = fig.suptitle('Correlation Heatmap', fontsize=18, fontweight='bold')

# %% [markdown]
# ### Barchart
# * To see count of each feature

# %%
target_col: str = "verified"
twitter_accounts_df2 = new_df_tweets.groupby([grouped, target_col])[grouped].count().unstack(target_col)
plot1 = twitter_accounts_df2.plot(kind='bar', stacked=False)
plt.xticks(rotation=0)
# bg = fig.patch
# bg.set_facecolor("white")
# plt.savefig(f'..\\Images\\Barchart\\{target_col}.jpg', facecolor=fig.get_facecolor())
add_labels(plot1)

# %%
target_col: str = "protected"
twitter_accounts_df2 = new_df_tweets.groupby([grouped, target_col])[grouped].count().unstack(target_col)
plot1 = twitter_accounts_df2.plot(kind='bar', stacked=False)
plt.xticks(rotation=0)
# bg = fig.patch
# bg.set_facecolor("white")
# plt.savefig(f'..\\Images\\Barchart\\{target_col}.jpg', facecolor=fig.get_facecolor())
add_labels(plot1)

# %%
target_col: str = "has_description"
twitter_accounts_df2 = new_df_tweets.groupby([grouped, target_col])[grouped].count().unstack(target_col)
plot2 = twitter_accounts_df2.plot(kind='bar', stacked=False)
plt.xticks(rotation=0) 
# bg = fig.patch
# bg.set_facecolor("white")
# plt.savefig(f'..\\Images\\Barchart\\{target_col}.jpg', facecolor=fig.get_facecolor())
add_labels(plot2)

# %%
target_col: str = "un_special_char"
twitter_accounts_df2 = new_df_tweets.groupby([grouped, target_col])[grouped].count().unstack(target_col)
plot = twitter_accounts_df2.plot(kind='bar', stacked=False)
plt.xticks(rotation=0)
# bg = fig.patch
# bg.set_facecolor("white")
# plt.savefig(f'..\\Images\\Barchart\\{target_col}.jpg', facecolor=fig.get_facecolor())
add_labels(plot)

# %%
target_col: str = "un_uppercase"
twitter_accounts_df2 = new_df_tweets.groupby([grouped, target_col])[grouped].count().unstack(target_col)
plot = twitter_accounts_df2.plot(kind='bar', stacked=False)
plt.xticks(rotation=0)  
# bg = fig.patch
# bg.set_facecolor("white")
# plt.savefig(f'..\\Images\\Barchart\\{target_col}.jpg', facecolor=fig.get_facecolor())
add_labels(plot)

# %%
target_col: str = "name_special_char"
twitter_accounts_df2 = new_df_tweets.groupby([grouped, target_col])[grouped].count().unstack(target_col)
plot = twitter_accounts_df2.plot(kind='bar', stacked=False)
plt.xticks(rotation=0) 
# bg = fig.patch
# bg.set_facecolor("white")
# plt.savefig(f'..\\Images\\Barchart\\{target_col}.jpg', facecolor=fig.get_facecolor())
add_labels(plot)

# %%
target_col: str = "name_uppercase"
twitter_accounts_df2 = new_df_tweets.groupby([grouped, target_col])[grouped].count().unstack(target_col)
plot = twitter_accounts_df2.plot(kind='bar', stacked=False)
plt.xticks(rotation=0) 
# bg = fig.patch
# bg.set_facecolor("white")
# plt.savefig(f'..\\Images\\Barchart\\{target_col}.jpg', facecolor=fig.get_facecolor())
add_labels(plot)

# %%
target_col: str = "des_external_links"
twitter_accounts_df2 = new_df_tweets.groupby([grouped, target_col])[grouped].count().unstack(target_col)
plot = twitter_accounts_df2.plot(kind='bar', stacked=False)
plt.xticks(rotation=0) 
# bg = fig.patch
# bg.set_facecolor("white")
# plt.savefig(f'..\\Images\\Barchart\\{target_col}.jpg', facecolor=fig.get_facecolor())
add_labels(plot)

# %%
target_col: str = "location"
twitter_accounts_df2 = new_df_tweets.groupby([grouped, target_col])[grouped].count().unstack(target_col)
plot3 = twitter_accounts_df2.plot(kind='bar', stacked=False)
plt.xticks(rotation=0) 
# bg = fig.patch
# bg.set_facecolor("white")
# plt.savefig(f'..\\Images\\Barchart\\{target_col}.jpg', facecolor=fig.get_facecolor())
add_labels(plot3)

# %% [markdown]
# ### Histogram and Boxplot

# %%
target: str = "tweet_count"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)
s = skew(new_df_tweets['tweet_count'])
print (f'Skewness: {s}') #data is very skewed

#We log transform tweet_count to make trends in the data more interpretable. 
new_df_tweets['tweet_count_log'] = np.round(np.log(1 + new_df_tweets['tweet_count']), 3)
target: str = "tweet_count_log"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)
# Extract Box-plots
plot_multiple_boxplots(data=new_df_tweets,
                       grouped_col=grouped,
                       target_col=target,
                       palette=palette)
# Out:
# Skewness: 15.263157442338843

# %%
target: str = "followers_count"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)
s = skew(new_df_tweets['followers_count'])
print (f'Skewness: {s}') #data is very skewed

#We log transform followers_count to make trends in the data more interpretable. 
new_df_tweets['followers_count_log'] = np.round(np.log(1 + new_df_tweets['followers_count']), 3)
target: str = "followers_count_log"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)
# Extract Box-plots
plot_multiple_boxplots(data=new_df_tweets,
                       grouped_col=grouped,
                       target_col=target,
                       palette=palette)
# Out:
# Skewness: 22.546208168651493

# %%
target: str = "following_count"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)
s = skew(new_df_tweets['following_count'])
print (f'Skewness: {s}') #data is very skewed

#We log transform followers_count to make trends in the data more interpretable. 
new_df_tweets['following_count_log'] = np.round(np.log(1 + new_df_tweets['following_count']), 3)
target: str = "following_count_log"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)
# Extract Box-plots
plot_multiple_boxplots(data=new_df_tweets,
                       grouped_col=grouped,
                       target_col=target,
                       palette=palette)
# Out:
# Skewness: 36.55292693381353

# %%
target: str = "account_age_in_days"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)

s = skew(new_df_tweets['account_age_in_days'])
print (f'Skewness: {s}') #data distribution is fairly symmetrical

# Extract Box-plots
plot_multiple_boxplots(data=new_df_tweets,
                       grouped_col=grouped,
                       target_col=target,
                       palette=palette)
# Out:
# Skewness: -0.553041750320028

# %%
target: str = "un_no_of_char"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)

s = skew(new_df_tweets['un_no_of_char'])
print (f'Skewness: {s}') #data distribution is fairly symmetrical

# Extract Box-plots
plot_multiple_boxplots(data=new_df_tweets,
                       grouped_col=grouped,
                       target_col=target,
                       palette=palette)
# Out:
# Skewness: -0.2788251544430134

# %%
target: str = "name_no_of_char"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)

s = skew(new_df_tweets['name_no_of_char'])
print (f'Skewness: {s}') #data distribution is fairly symmetrical

# Extract Box-plots
plot_multiple_boxplots(data=new_df_tweets,
                       grouped_col=grouped,
                       target_col=target,
                       palette=palette)
# Out:
# Skewness: 1.311577732205691

# %%
target: str = "des_no_of_usertags"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)

s = skew(new_df_tweets['des_no_of_usertags'])
print (f'Skewness: {s}') #data is slightly skewed

#We log transform followers_count to make trends in the data more interpretable. 
new_df_tweets['des_no_of_usertags_log'] = np.round(np.log(1 + new_df_tweets['des_no_of_usertags']), 3)
target: str = "des_no_of_usertags_log" 

# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)

# Extract Box-plots
plot_multiple_boxplots(data=new_df_tweets,
                       grouped_col=grouped,
                       target_col=target,
                       palette=palette)
# Out:
# Skewness: 4.5052506223975985

# %%
target: str = "des_no_of_hashtags"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)

s = skew(new_df_tweets['des_no_of_hashtags'])
print (f'Skewness: {s}') #data is slightly skewed

#We log transform followers_count to make trends in the data more interpretable. 
new_df_tweets['des_no_of_hashtags_log'] = np.round(np.log(1 + new_df_tweets['des_no_of_hashtags']), 3)
target: str = "des_no_of_hashtags_log"  
# Extract histograms
plot_multiple_histograms(data=new_df_tweets, 
                         grouped_col=grouped,
                         data_labels=data_labels,
                         target_col=target)

# Extract Box-plots
plot_multiple_boxplots(data=new_df_tweets,
                       grouped_col=grouped,
                       target_col=target,
                       palette=palette)
# Out:
# Skewness: 6.244224310412954

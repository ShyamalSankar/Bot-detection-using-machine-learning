# %% [markdown]
# # Wordcloud
#
# In this part, we shall create notebooks for the wordcloud for the bot tweets and the human tweets. This is to get a general sense of the type of words used in both kinds of tweets

# %%
#import libraries needed for this step
import pandas as pd
import numpy as np
import re
import emoji
import nltk
import language_tool_python
import warnings

import seaborn as sns
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ruthk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ruthk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ruthk\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ruthk\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
#Reading in the data
human_tweets = pd.read_csv('human_tweets_processed.csv')

# %%
human_tweets.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                  id  \
# 0           0             0         1555987  549097411394940928
# 1           1             1         1585626  566021410649145345
# 2           2             3         1916698  489188089143648256
# 3           3             5         1269997  494612842679517186
# 4           4             8         2537638  572308471829299200
#
#                                                 text  \
# 0          @KyleDavidHall @YouTube YASS  THANKS BABE
# 1  RT @AbnInfVet: ...And Then Bloomberg Says He D...
# 2  RT @lgbtqnation: Federal judge considers separ...
# 3  RT @OKFosterWishes: URGENT; Beds needed to get...
# 4  RT @luke_brooks: N.America and EU! Our EP "Wou...
#
#                                               source       user_id  \
# 0  <a href="http://twitter.com/download/iphone" r...  2.193435e+09
# 1  <a href="http://twitter.com" rel="nofollow">Tw...  2.198399e+09
# 2  <a href="http://twitter.com/download/iphone" r...  2.244691e+09
# 3  <a href="http://twitter.com/download/iphone" r...  1.752381e+07
# 4  <a href="http://twitter.com/download/iphone" r...  2.312113e+08
#
#    retweeted_status_id  retweet_count  reply_count  favorite_count  \
# 0         0.000000e+00            0.0          0.0             0.0
# 1         5.660208e+17           11.0          0.0             0.0
# 2         4.891829e+17           10.0          0.0             0.0
# 3         4.945571e+17            6.0          0.0             0.0
# 4         5.722651e+17         3587.0          0.0             0.0
#
#    num_hashtags  num_urls  num_mentions                      created_at  bot  \
# 0           0.0       0.0           2.0  Sun Dec 28 06:59:59 +0000 2014    0
# 1           3.0       0.0           1.0  Thu Feb 12 23:49:55 +0000 2015    0
# 2           1.0       1.0           1.0  Tue Jul 15 23:21:43 +0000 2014    0
# 3           0.0       1.0           1.0  Wed Jul 30 22:37:45 +0000 2014    0
# 4           0.0       1.0           1.0  Mon Mar 02 08:12:27 +0000 2015    0
#
#                                         cleaned_text
# 0  __user_mention__ __user_mention__ YASS THANKS ...
# 1  RT __user_mention__ ...And Then Bloomberg Says...
# 2  RT __user_mention__ Federal judge considers se...
# 3  RT __user_mention__ URGENT; Beds needed to get...
# 4  RT __user_mention__ N.America and EU! Our EP "...

# %%
#We shall use the already cleaned tweets for this task
human_tweets_text = human_tweets[['cleaned_text']].copy()

# %%
bot_tweets_social = pd.read_csv('bot_tweets_social_processed.csv')

# %%
bot_tweets_fake = pd.read_csv('bot_tweets_fake_processed.csv')

# %%
bot_tweets_social_text = bot_tweets_social[['cleaned_text']].copy()
bot_tweets_fake_text = bot_tweets_fake[['cleaned_text']].copy()

# %% [markdown]
# ## Human Tweets

# %%
#First, we shall generate the wordcloud for human users

human_tweets_text['tokenized'] = human_tweets_text['cleaned_text'].apply(word_tokenize)

# %%
human_tweets_text.head()
# Out:
#                                         cleaned_text  \
# 0  __user_mention__ __user_mention__ YASS THANKS ...
# 1  RT __user_mention__ ...And Then Bloomberg Says...
# 2  RT __user_mention__ Federal judge considers se...
# 3  RT __user_mention__ URGENT; Beds needed to get...
# 4  RT __user_mention__ N.America and EU! Our EP "...
#
#                                            tokenized
# 0  [__user_mention__, __user_mention__, YASS, THA...
# 1  [RT, __user_mention__, ..., And, Then, Bloombe...
# 2  [RT, __user_mention__, Federal, judge, conside...
# 3  [RT, __user_mention__, URGENT, ;, Beds, needed...
# 4  [RT, __user_mention__, N.America, and, EU, !, ...

# %%
#include the list of stop words and contextual stop words and instantiate a lemmatizer
stop = set(stopwords.words('english'))
contextual_stop = ["__user_mention__", "__hashtag__", "rt", "u", 'r', 't']
lemmatizer = WordNetLemmatizer()

# %%
#remove all stop words
human_tweets_text['processed_data'] = human_tweets_text.tokenized.apply(lambda x: [word.casefold() for word in x if word.casefold() not in stop
                                                                        and word not in contextual_stop])
#perform lemmatization
human_tweets_text['processed_data'] = human_tweets_text.processed_data.apply(lambda x:[lemmatizer.lemmatize(word) for word in x])

# %%
#join the processed tokens to form a sentence
human_tweets_text['sentence'] = human_tweets_text['processed_data'].apply(lambda x:' '.join(x))

# %%
#Create a big sentence for humans joining all human tweets together
big_sentence = ''

for sentence in human_tweets_text['sentence']:
    big_sentence += sentence
    
wordcloud = WordCloud(background_color = "white").generate(text = big_sentence)
wordcloud.process_text()
plt.figure(figsize=(12,12))
plt.imshow(wordcloud, interpolation = 'bilinear')

# %% [markdown]
# ## Bot Tweets

# %%
#now we do the same for bots
bot_tweets_text = pd.concat([bot_tweets_social_text, bot_tweets_fake_text], axis = 0)

# %%
bot_tweets_text['tokenized'] = bot_tweets_text['cleaned_text'].apply(word_tokenize)

# %%
#remove all stop words
bot_tweets_text['processed_data'] = bot_tweets_text.tokenized.apply(lambda x: [word.casefold() for word in x if word.casefold() not in stop
                                                                        and word not in contextual_stop])
#perform lemmatization
bot_tweets_text['processed_data'] = bot_tweets_text.processed_data.apply(lambda x:[lemmatizer.lemmatize(word) for word in x])

# %%
#join the processed tokens to form a sentence
bot_tweets_text['sentence'] = bot_tweets_text['processed_data'].apply(lambda x:' '.join(x))

# %%
#Create a big sentence for bots joining all bot tweets together
big_sentence = ''

for sentence in bot_tweets_text['sentence']:
    big_sentence += sentence
    
wordcloud = WordCloud(background_color = "white").generate(text = big_sentence)
plt.figure(figsize=(12,12))
plt.imshow(wordcloud, interpolation = 'bilinear')

# %% [markdown]
# # Analysing Textual Features

# %%
df_tweets_all = pd.concat([human_tweets, bot_tweets_fake, bot_tweets_social])
df_tweets_all = df_tweets_all.reset_index(inplace = False, drop = True)

# %%
df_tweets_all = df_tweets_all.rename(columns = {"bot": "account_type"})
df_tweets_all
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                  id  \
# 0                0             0         1555987  549097411394940928
# 1                1             1         1585626  566021410649145345
# 2                2             3         1916698  489188089143648256
# 3                3             5         1269997  494612842679517186
# 4                4             8         2537638  572308471829299200
# ...            ...           ...             ...                 ...
# 248177       42222         99990          125115  224967602886279168
# 248178       42223         99991          138446  218760002142351361
# 248179       42224         99993          117139  314267535916814336
# 248180       42225         99998          141229  312307989212192769
# 248181       42226         99999          104778  297309617199906816
#
#                                                      text  \
# 0               @KyleDavidHall @YouTube YASS  THANKS BABE
# 1       RT @AbnInfVet: ...And Then Bloomberg Says He D...
# 2       RT @lgbtqnation: Federal judge considers separ...
# 3       RT @OKFosterWishes: URGENT; Beds needed to get...
# 4       RT @luke_brooks: N.America and EU! Our EP "Wou...
# ...                                                   ...
# 248177  theawkwardmoment#theawkwardmoment when you sta...
# 248178  I will have the rest of the site updated when ...
# 248179  RT @EMANSANGELS: Follow @scottstorch and view ...
# 248180             Stupidity in numbers.  penn state riot
# 248181  RT @Srkrokx: Website Rank | Search Engine Opti...
#
#                                                    source       user_id  \
# 0       <a href="http://twitter.com/download/iphone" r...  2.193435e+09
# 1       <a href="http://twitter.com" rel="nofollow">Tw...  2.198399e+09
# 2       <a href="http://twitter.com/download/iphone" r...  2.244691e+09
# 3       <a href="http://twitter.com/download/iphone" r...  1.752381e+07
# 4       <a href="http://twitter.com/download/iphone" r...  2.312113e+08
# ...                                                   ...           ...
# 248177                                                web  6.162121e+08
# 248178                                                web  6.162873e+08
# 248179                                                web  4.757323e+08
# 248180                                                web  6.162999e+08
# 248181                                                web  3.493928e+08
#
#         retweeted_status_id  retweet_count  reply_count  favorite_count  \
# 0              0.000000e+00            0.0          0.0             0.0
# 1              5.660208e+17           11.0          0.0             0.0
# 2              4.891829e+17           10.0          0.0             0.0
# 3              4.945571e+17            6.0          0.0             0.0
# 4              5.722651e+17         3587.0          0.0             0.0
# ...                     ...            ...          ...             ...
# 248177                  NaN            0.0          0.0             0.0
# 248178                  NaN            0.0          0.0             0.0
# 248179                  NaN        13783.0          0.0             0.0
# 248180                  NaN            0.0          0.0             0.0
# 248181                  NaN          797.0          0.0             0.0
#
#         num_hashtags  num_urls  num_mentions                      created_at  \
# 0                0.0       0.0           2.0  Sun Dec 28 06:59:59 +0000 2014
# 1                3.0       0.0           1.0  Thu Feb 12 23:49:55 +0000 2015
# 2                1.0       1.0           1.0  Tue Jul 15 23:21:43 +0000 2014
# 3                0.0       1.0           1.0  Wed Jul 30 22:37:45 +0000 2014
# 4                0.0       1.0           1.0  Mon Mar 02 08:12:27 +0000 2015
# ...              ...       ...           ...                             ...
# 248177           1.0       0.0           0.0  Mon Jul 16 20:43:50 +0000 2012
# 248178           0.0       0.0           0.0  Fri Jun 29 17:37:03 +0000 2012
# 248179           0.0       0.0           2.0  Wed Mar 20 06:49:54 +0000 2013
# 248180           0.0       0.0           0.0  Thu Mar 14 21:03:21 +0000 2013
# 248181           0.0       1.0           1.0  Fri Feb 01 11:45:11 +0000 2013
#
#         account_type                                       cleaned_text
# 0                  0  __user_mention__ __user_mention__ YASS THANKS ...
# 1                  0  RT __user_mention__ ...And Then Bloomberg Says...
# 2                  0  RT __user_mention__ Federal judge considers se...
# 3                  0  RT __user_mention__ URGENT; Beds needed to get...
# 4                  0  RT __user_mention__ N.America and EU! Our EP "...
# ...              ...                                                ...
# 248177             1  theawkwardmoment#theawkwardmoment when you sta...
# 248178             1  I will have the rest of the site updated when ...
# 248179             1  RT __user_mention__ Follow __user_mention__ an...
# 248180             1              Stupidity in numbers. penn state riot
# 248181             1  RT __user_mention__ Website Rank | Search Engi...
#
# [248182 rows x 17 columns]

# %% [markdown]
# ## Barplots and Stripplots

# %% [markdown]
# ### Retweet Count

# %%
sns.barplot(data = df_tweets_all, x = "account_type", y = "retweet_count")
# Out:
# <AxesSubplot:xlabel='account_type', ylabel='retweet_count'>

# %%
sns.stripplot(data = df_tweets_all, x = "account_type", y = "retweet_count")
# Out:
# <AxesSubplot:xlabel='account_type', ylabel='retweet_count'>

# %% [markdown]
# ### Favourite Count

# %%
sns.barplot(data = df_tweets_all, x = "account_type", y = "favorite_count")
# Out:
# <AxesSubplot:xlabel='account_type', ylabel='favorite_count'>

# %%
sns.stripplot(data = df_tweets_all, x = "account_type", y = "favorite_count")
# Out:
# <AxesSubplot:xlabel='account_type', ylabel='favorite_count'>

# %% [markdown]
# ### Num of Hashtags

# %%
sns.barplot(data = df_tweets_all, x = "account_type", y = "num_hashtags")
# Out:
# <AxesSubplot:xlabel='account_type', ylabel='num_hashtags'>

# %%
sns.stripplot(data = df_tweets_all, x = "account_type", y = "num_hashtags")
# Out:
# <AxesSubplot:xlabel='account_type', ylabel='num_hashtags'>

# %% [markdown]
# ### Num of URLs

# %%
sns.barplot(data = df_tweets_all, x = "account_type", y = "num_urls")
# Out:
# <AxesSubplot:xlabel='account_type', ylabel='num_urls'>

# %%
sns.stripplot(data = df_tweets_all, x = "account_type", y = "num_urls")
# Out:
# <AxesSubplot:xlabel='account_type', ylabel='num_urls'>

# %% [markdown]
# ### Num of Mentions

# %%
sns.barplot(data = df_tweets_all, x = "account_type", y = "num_mentions")
# Out:
# <AxesSubplot:xlabel='account_type', ylabel='num_mentions'>

# %%
sns.stripplot(data = df_tweets_all, x = "account_type", y = "num_mentions")
# Out:
# <AxesSubplot:xlabel='account_type', ylabel='num_mentions'>

# %% [markdown]
# ## Correlation Analysis

# %%
human_tweets = df_tweets_all[df_tweets_all['account_type'] == 0]
bot_tweets = df_tweets_all[df_tweets_all['account_type'] == 1]

# %%
relevant_values_human = human_tweets[['retweet_count','num_hashtags', 'num_urls', 'num_mentions']]
sns.heatmap(relevant_values_human.corr(),cmap ='coolwarm', annot=True,)
# Out:
# <AxesSubplot:>

# %%
relevant_values_bot = bot_tweets[['retweet_count','num_hashtags', 'num_urls', 'num_mentions']]
sns.heatmap(relevant_values_bot.corr(),cmap ='coolwarm', annot=True,)
# Out:
# <AxesSubplot:>
